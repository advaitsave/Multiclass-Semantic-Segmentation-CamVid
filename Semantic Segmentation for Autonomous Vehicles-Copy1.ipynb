# %% [markdown]
# # Semantic Segmentation for Autonomous Vehicles

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Environment checks

# %%
print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))
# Out:
# Is there a GPU available:
# True
# Is the Tensor on GPU #0:
# True
# Device name: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(tf.executing_eagerly())
# Out:
# True

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Functions to read and separate frames from masks

# %%
def _read_to_tensor(fname, output_height=256, output_width=512, normalize_data=False):
    '''Original images are 256 x 512 x 3. Left half is original image, right is semantic seg'''
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    if normalize_data:
        output = (output - 128) / 128
    return output

def _get_left_img_half(inp, width=256):
    return inp[:, :width, :]

def _get_right_img_half(inp, width=256):
    return inp[:, width:, :]

# %% [markdown]
# ### Reading and separating frames and masks

# %%
train_img_dir = 'data/cityscapes_data/train'
val_img_dir = 'data/cityscapes_data/val'

# Start with a dataset of directory names.
output_height = 256
output_width = 256

def separate_frames_masks(img_dir):
    file_list = os.listdir(img_dir)
    img_paths = [os.path.join(img_dir, fname) for fname in file_list]
    my_data = tf.data.Dataset.from_tensor_slices(img_paths)
    img_tensors = my_data.map(_read_to_tensor)
    frames = img_tensors.map(_get_left_img_half)
    masks = img_tensors.map(_get_right_img_half)
    return frames, masks, file_list

train_frames, train_masks, train_files = separate_frames_masks(train_img_dir)
val_frames, val_masks, val_files = separate_frames_masks(val_img_dir)

# %% [markdown]
# ### Displaying Images in the train dataset

# %%
frame_batches = tf.compat.v1.data.make_one_shot_iterator(train_frames)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(train_masks)
n_images_to_show = 5

for i in range(n_images_to_show):

    frame = frame_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.imshow(mask)
    plt.show()

# %% [markdown]
# ### Creating folder structure common to Computer Vision problems

# %%
DATA_PATH = 'data/cityscapes_data/'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'data/cityscapes_data/train_frames/train'
# [WinError 183] Cannot create a file when that file already exists: 'data/cityscapes_data/train_masks/train'
# [WinError 183] Cannot create a file when that file already exists: 'data/cityscapes_data/val_frames/val'
# [WinError 183] Cannot create a file when that file already exists: 'data/cityscapes_data/val_masks/val'

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
def generate_image_folder_structure(frames, masks, files, dir_name):
    
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the images while saving the frames and masks in appropriate folders
    for file in files:
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file)
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file)
    
    print("Saved {} frames to directory {}".format(len(files),DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'))
    print("Saved {} masks to directory {}".format(len(files),DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'))
    
generate_image_folder_structure(train_frames, train_masks, train_files, 'train')

generate_image_folder_structure(train_frames, train_masks, val_files, 'val')
# Out:
# Saved 2975 frames to directory data/cityscapes_data/train_frames/train/
# Saved 2975 masks to directory data/cityscapes_data/train_masks/train/
# Saved 500 frames to directory data/cityscapes_data/val_frames/val/
# Saved 500 masks to directory data/cityscapes_data/val_masks/val/

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add

from tensorflow.compat.v1.layers import conv2d_transpose

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
input_shape=(256,256,3)
weight_decay=0.
batch_momentum=0.9
batch_shape=(8,256,256,3)
classes=21
img_input = Input(batch_shape=batch_shape)
img_input
# Out:
# <tf.Tensor 'input_1:0' shape=(8, 256, 256, 3) dtype=float32>

# %%
data_gen_args = dict(rescale=1./255)
train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**data_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**data_gen_args)

seed = 1

# %%
train_image_generator = train_frames_datagen.flow_from_directory(
'data/cityscapes_data/train_frames/',
batch_size = 8)

train_mask_generator = train_masks_datagen.flow_from_directory(
'data/cityscapes_data/train_masks/',
batch_size = 8)

val_image_generator = val_frames_datagen.flow_from_directory(
'data/cityscapes_data/val_frames/',
batch_size = 8)


val_mask_generator = val_masks_datagen.flow_from_directory(
'data/cityscapes_data/val_masks/',
batch_size = 8)



train_generator = (train_image_generator, train_mask_generator)
val_generator = (val_image_generator, val_mask_generator)
# Out:
# Found 2975 images belonging to 1 classes.
# Found 2975 images belonging to 1 classes.
# Found 500 images belonging to 1 classes.
# Found 500 images belonging to 1 classes.

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 5):
    train_image_generator = train_frames_datagen.flow_from_directory(
    'data/cityscapes_data/train_frames/',
    batch_size = batch_size, seed = seed)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    'data/cityscapes_data/train_masks/',
    batch_size = batch_size, seed = seed)

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        yield X1i[0], X2i[0]

def ValAugmentGenerator(seed = 1, batch_size = 5):
    val_image_generator = val_frames_datagen.flow_from_directory(
    'data/cityscapes_data/val_frames/',
    batch_size = batch_size, seed = seed)


    val_mask_generator = val_masks_datagen.flow_from_directory(
    'data/cityscapes_data/val_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        yield X1i[0], X2i[0]

# %%
from tensorflow.keras import backend as K
if K.image_data_format() == 'channels_first':
    input_shape = (8,3, 256,256)
else:
    input_shape = (8,256,256,3)

# %%
def get_small_unet(n_filters = 16, bn = True):
    #inputs = Input((img_rows, img_cols,3))
    #inputs_norm = Lambda(lambda x: x/127.5 - 1.)
    batch_shape=(256,256,3)
    classes=21
    inputs = Input(batch_shape=(5, 256, 256, 3))
    print(inputs)
    
    conv1 = Conv2D(8, (3, 3), activation='relu', padding = 'same')(inputs)
    conv1 = Conv2D(8, (3, 3), activation='relu', padding = 'same')(conv1)
    
    if bn:
        conv1 = BatchNormalization()(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv1)

    conv2 = Conv2D(16, (3, 3), activation='relu', padding = 'same')(pool1)
    conv2 = Conv2D(16, (3, 3), activation='relu', padding = 'same')(conv2)
    
    
    if bn:
        conv2 = BatchNormalization()(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv2)

    conv3 = Conv2D(32, (3, 3), activation='relu', padding = 'same')(pool2)
    conv3 = Conv2D(32, (3, 3), activation='relu', padding = 'same')(conv3)
    
    
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    pool3 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv3)

    conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same')(pool3)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same')(conv4)
    
    
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    pool4 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv4)

    conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(pool4)
    conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(conv5)
    
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=3)
    conv6 = Conv2D(64, (3, 3), activation='relu', padding = 'same')(up6)
    conv6 = Conv2D(64, (3, 3), activation='relu', padding = 'same')(conv6)

    if bn:
        conv6 = BatchNormalization()(conv6)
        
    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=3)
    conv7 = Conv2D(32, (3, 3), activation='relu', padding = 'same')(up7)
    conv7 = Conv2D(32, (3, 3), activation='relu', padding = 'same')(conv7)

    if bn:
        conv7 = BatchNormalization()(conv7)
        
    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=3)
    conv8 = Conv2D(16, (3, 3), activation='relu', padding = 'same')(up8)
    conv8 = Conv2D(16, (3, 3), activation='relu', padding = 'same')(conv8)

    if bn:
        conv8 = BatchNormalization()(conv8)
        
    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=3)
    conv9 = Conv2D(8, (3, 3), activation='relu', padding = 'same')(up9)
    conv9 = Conv2D(8, (3, 3), activation='relu', padding = 'same')(conv9)
    
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv10 = Conv2D(3, (1, 1), activation='sigmoid', padding = 'same')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    
    return model

# %%
model = get_small_unet(n_filters = 32)
# Out:
# Tensor("input_4:0", shape=(5, 256, 256, 3), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-b90c2153e3f4> in <module>()
# ----> 1 model = get_small_unet(n_filters = 32)
#
# <ipython-input-17-ed9971f6d668> in get_small_unet(n_filters, bn)
#      20
#      21     if bn:
# ---> 22         conv2 = BatchNormalization()(conv2)
#      23
#      24     pool2 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv2)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     592           # Build layer if applicable (if the `build` method has been
#     593           # overridden).
# --> 594           self._maybe_build(inputs)
#     595           # Explicitly pass the learning phase placeholder to `call` if
#     596           # the `training` argument was left unspecified by the user.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    1711     # Only call `build` if the user has manually overridden the build method.
#    1712     if not hasattr(self.build, '_is_default'):
# -> 1713       self.build(input_shapes)
#    1714     # We must set self.built since user defined build functions are not
#    1715     # constrained to set self.built.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\normalization.py in build(self, input_shape)
#     338           constraint=self.gamma_constraint,
#     339           trainable=True,
# --> 340           experimental_autocast=False)
#     341     else:
#     342       self.gamma = None
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     375         collections=collections,
#     376         synchronization=synchronization,
# --> 377         aggregation=aggregation)
#     378     backend.track_variable(variable)
#     379
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     620     new_variable = getter(
#     621         name=name, shape=shape, dtype=dtype, initializer=initializer,
# --> 622         **kwargs_for_getter)
#     623
#     624     # If we set an initializer and the variable processed it, tracking will not
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     150       collections=collections,
#     151       synchronization=synchronization,
# --> 152       aggregation=aggregation)
#     153   return v
#     154
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     210   def __call__(cls, *args, **kwargs):
#     211     if cls is VariableV1:
# --> 212       return cls._variable_v1_call(*args, **kwargs)
#     213     elif cls is Variable:
#     214       return cls._variable_v2_call(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation)
#     173         use_resource=use_resource,
#     174         synchronization=synchronization,
# --> 175         aggregation=aggregation)
#     176
#     177   def _variable_v2_call(cls,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kwargs)
#     152                         aggregation=VariableAggregation.NONE):
#     153     """Call on Variable class. Useful to force the signature."""
# --> 154     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     155     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     156       previous_getter = _make_getter(getter, previous_getter)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2490         caching_device=caching_device, name=name, dtype=dtype,
#    2491         constraint=constraint, variable_def=variable_def,
# -> 2492         import_scope=import_scope, distribute_strategy=distribute_strategy)
#    2493   else:
#    2494     return variables.RefVariable(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     214       return cls._variable_v2_call(*args, **kwargs)
#     215     else:
# --> 216       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     217
#     218
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy)
#     420           name=name,
#     421           dtype=dtype,
# --> 422           constraint=constraint)
#     423
#     424   def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint)
#     549               shared_name=shared_name,
#     550               name=name,
# --> 551               graph_mode=self._in_graph_mode)
#     552         self._shape = initial_value.shape
#     553         # pylint: disable=protected-access
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in eager_safe_variable_handle(initial_value, shared_name, name, graph_mode)
#     193                        "get_variable() if reuse is desired." %
#     194                        shared_name)
# --> 195     with context.graph_mode(), ops.Graph().as_default() as graph:
#     196       h = gen_resource_variable_ops.var_handle_op(shape=shape, dtype=dtype,
#     197                                                   shared_name=shared_name,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self)
#    3066     # TODO(skyewm): fold as much of the above as possible into the C
#    3067     # implementation
# -> 3068     self._scoped_c_graph = c_api_util.ScopedTFGraph()
#    3069     # The C API requires all ops to have shape functions. Disable this
#    3070     # requirement (many custom ops do not have shape functions, and we don't
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\c_api_util.py in __init__(self)
#      44
#      45   def __init__(self):
# ---> 46     self.graph = c_api.TF_NewGraph()
#      47
#      48   def __del__(self):
#
# KeyboardInterrupt:

# %%
### IOU or dice coeff calculation

def IOU_calc(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return 2*(intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def IOU_calc_loss(y_true, y_pred):
    return -IOU_calc(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
smooth = 1.

# %%
model.compile(optimizer=Adam(lr=1e-5), loss="categorical_crossentropy", metrics=[IOU_calc,'accuracy'])

# %%
model.summary()

# %%
batch_size=5

# %%
np.ceil(float(len(train_files)) / float(batch_size))
# Out:
# 595.0

# %%
len(train_files)
# Out:
# 2975

# %%
(float(len(val_files)) / float(batch_size))
# Out:
# 100.0

# %%
train_generator
# Out:
# (<keras_preprocessing.image.directory_iterator.DirectoryIterator at 0x1d5d864f748>,
#  <keras_preprocessing.image.directory_iterator.DirectoryIterator at 0x1d5d864f0f0>)

# %%
# Train model

batch_size = 5
model.fit_generator(TrainAugmentGenerator(), steps_per_epoch=595,
                validation_data = ValAugmentGenerator(), 
                validation_steps = 100, epochs=50)
model.save_weights("model_100_epochs.h5", overwrite=True)
# Out:
# Found 2975 images belonging to 1 classes.
# Found 2975 images belonging to 1 classes.
# Epoch 1/50
# 594/595 [============================>.] - ETA: 0s - loss: 0.6663 - IOU_calc: 0.3753 - accuracy: 0.0691Found 500 images belonging to 1 classes.
# Found 500 images belonging to 1 classes.
# 595/595 [==============================] - 42s 71ms/step - loss: 0.6663 - IOU_calc: 0.3753 - accuracy: 0.0691 - val_loss: 0.6387 - val_IOU_calc: 0.3679 - val_accuracy: 0.0826
# Epoch 2/50
# 595/595 [==============================] - 35s 59ms/step - loss: 0.6382 - IOU_calc: 0.3681 - accuracy: 0.0726 - val_loss: 0.6283 - val_IOU_calc: 0.3617 - val_accuracy: 0.0836
# Epoch 3/50
# 595/595 [==============================] - 37s 63ms/step - loss: 0.6321 - IOU_calc: 0.3700 - accuracy: 0.0726 - val_loss: 0.6240 - val_IOU_calc: 0.3728 - val_accuracy: 0.0833
# Epoch 4/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6286 - IOU_calc: 0.3729 - accuracy: 0.0726 - val_loss: 0.6211 - val_IOU_calc: 0.3697 - val_accuracy: 0.0827
# Epoch 5/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6258 - IOU_calc: 0.3749 - accuracy: 0.0726 - val_loss: 0.6182 - val_IOU_calc: 0.3762 - val_accuracy: 0.0832
# Epoch 6/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6236 - IOU_calc: 0.3764 - accuracy: 0.0726 - val_loss: 0.6163 - val_IOU_calc: 0.3793 - val_accuracy: 0.0834
# Epoch 7/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6216 - IOU_calc: 0.3778 - accuracy: 0.0726 - val_loss: 0.6138 - val_IOU_calc: 0.3795 - val_accuracy: 0.0832
# Epoch 8/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6194 - IOU_calc: 0.3794 - accuracy: 0.0726 - val_loss: 0.6118 - val_IOU_calc: 0.3795 - val_accuracy: 0.0835
# Epoch 9/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6174 - IOU_calc: 0.3812 - accuracy: 0.0726 - val_loss: 0.6092 - val_IOU_calc: 0.3790 - val_accuracy: 0.0836
# Epoch 10/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6155 - IOU_calc: 0.3832 - accuracy: 0.0726 - val_loss: 0.6071 - val_IOU_calc: 0.3838 - val_accuracy: 0.0834
# Epoch 11/50
# 595/595 [==============================] - 39s 65ms/step - loss: 0.6136 - IOU_calc: 0.3848 - accuracy: 0.0726 - val_loss: 0.6066 - val_IOU_calc: 0.3811 - val_accuracy: 0.0815
# Epoch 12/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6118 - IOU_calc: 0.3860 - accuracy: 0.0726 - val_loss: 0.6036 - val_IOU_calc: 0.3827 - val_accuracy: 0.0845
# Epoch 13/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6102 - IOU_calc: 0.3872 - accuracy: 0.0726 - val_loss: 0.6021 - val_IOU_calc: 0.3857 - val_accuracy: 0.0826
# Epoch 14/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6085 - IOU_calc: 0.3884 - accuracy: 0.0726 - val_loss: 0.5997 - val_IOU_calc: 0.3886 - val_accuracy: 0.0840
# Epoch 15/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.6070 - IOU_calc: 0.3899 - accuracy: 0.0726 - val_loss: 0.5990 - val_IOU_calc: 0.3881 - val_accuracy: 0.0830
# Epoch 16/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.6055 - IOU_calc: 0.3918 - accuracy: 0.0725 - val_loss: 0.5979 - val_IOU_calc: 0.3940 - val_accuracy: 0.0821
# Epoch 17/50
# 595/595 [==============================] - 37s 63ms/step - loss: 0.6040 - IOU_calc: 0.3936 - accuracy: 0.0725 - val_loss: 0.5952 - val_IOU_calc: 0.3925 - val_accuracy: 0.0835
# Epoch 18/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.6028 - IOU_calc: 0.3953 - accuracy: 0.0725 - val_loss: 0.5945 - val_IOU_calc: 0.3964 - val_accuracy: 0.0828
# Epoch 19/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.6018 - IOU_calc: 0.3967 - accuracy: 0.0725 - val_loss: 0.5937 - val_IOU_calc: 0.3960 - val_accuracy: 0.0825
# Epoch 20/50
# 595/595 [==============================] - 37s 63ms/step - loss: 0.6007 - IOU_calc: 0.3980 - accuracy: 0.0725 - val_loss: 0.5933 - val_IOU_calc: 0.4024 - val_accuracy: 0.0848
# Epoch 21/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5997 - IOU_calc: 0.3994 - accuracy: 0.0725 - val_loss: 0.5915 - val_IOU_calc: 0.3991 - val_accuracy: 0.0825
# Epoch 22/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5989 - IOU_calc: 0.4004 - accuracy: 0.0725 - val_loss: 0.5905 - val_IOU_calc: 0.3981 - val_accuracy: 0.0828
# Epoch 23/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5981 - IOU_calc: 0.4015 - accuracy: 0.0725 - val_loss: 0.5934 - val_IOU_calc: 0.4099 - val_accuracy: 0.0822
# Epoch 24/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5973 - IOU_calc: 0.4028 - accuracy: 0.0725 - val_loss: 0.5896 - val_IOU_calc: 0.4044 - val_accuracy: 0.0832
# Epoch 25/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5965 - IOU_calc: 0.4038 - accuracy: 0.0724 - val_loss: 0.5876 - val_IOU_calc: 0.4054 - val_accuracy: 0.0830
# Epoch 26/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5957 - IOU_calc: 0.4048 - accuracy: 0.0724 - val_loss: 0.5870 - val_IOU_calc: 0.4019 - val_accuracy: 0.0832
# Epoch 27/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5950 - IOU_calc: 0.4058 - accuracy: 0.0724 - val_loss: 0.5884 - val_IOU_calc: 0.4058 - val_accuracy: 0.0822
# Epoch 28/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5943 - IOU_calc: 0.4066 - accuracy: 0.0724 - val_loss: 0.5862 - val_IOU_calc: 0.4078 - val_accuracy: 0.0837
# Epoch 29/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5937 - IOU_calc: 0.4075 - accuracy: 0.0724 - val_loss: 0.5858 - val_IOU_calc: 0.4090 - val_accuracy: 0.0827
# Epoch 30/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5929 - IOU_calc: 0.4084 - accuracy: 0.0724 - val_loss: 0.5835 - val_IOU_calc: 0.4085 - val_accuracy: 0.0844
# Epoch 31/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5923 - IOU_calc: 0.4091 - accuracy: 0.0724 - val_loss: 0.5849 - val_IOU_calc: 0.4070 - val_accuracy: 0.0823
# Epoch 32/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5917 - IOU_calc: 0.4099 - accuracy: 0.0724 - val_loss: 0.5839 - val_IOU_calc: 0.4096 - val_accuracy: 0.0819
# Epoch 33/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5912 - IOU_calc: 0.4106 - accuracy: 0.0724 - val_loss: 0.5833 - val_IOU_calc: 0.4102 - val_accuracy: 0.0841
# Epoch 34/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5906 - IOU_calc: 0.4113 - accuracy: 0.0724 - val_loss: 0.5831 - val_IOU_calc: 0.4124 - val_accuracy: 0.0821
# Epoch 35/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5901 - IOU_calc: 0.4120 - accuracy: 0.0724 - val_loss: 0.5824 - val_IOU_calc: 0.4127 - val_accuracy: 0.0829
# Epoch 36/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5896 - IOU_calc: 0.4128 - accuracy: 0.0724 - val_loss: 0.5811 - val_IOU_calc: 0.4112 - val_accuracy: 0.0840
# Epoch 37/50
# 595/595 [==============================] - 37s 62ms/step - loss: 0.5892 - IOU_calc: 0.4134 - accuracy: 0.0724 - val_loss: 0.5812 - val_IOU_calc: 0.4129 - val_accuracy: 0.0821
# Epoch 38/50
# 595/595 [==============================] - 38s 65ms/step - loss: 0.5886 - IOU_calc: 0.4141 - accuracy: 0.0724 - val_loss: 0.5802 - val_IOU_calc: 0.4127 - val_accuracy: 0.0846
# Epoch 39/50
# 595/595 [==============================] - 40s 67ms/step - loss: 0.5883 - IOU_calc: 0.4148 - accuracy: 0.0725 - val_loss: 0.5804 - val_IOU_calc: 0.4133 - val_accuracy: 0.0819
# Epoch 40/50
# 595/595 [==============================] - 45s 76ms/step - loss: 0.5879 - IOU_calc: 0.4153 - accuracy: 0.0725 - val_loss: 0.5796 - val_IOU_calc: 0.4173 - val_accuracy: 0.0831
# Epoch 41/50
# 595/595 [==============================] - 41s 68ms/step - loss: 0.5874 - IOU_calc: 0.4159 - accuracy: 0.0725 - val_loss: 0.5812 - val_IOU_calc: 0.4101 - val_accuracy: 0.0816
# Epoch 42/50
# 595/595 [==============================] - 40s 67ms/step - loss: 0.5872 - IOU_calc: 0.4163 - accuracy: 0.0725 - val_loss: 0.5776 - val_IOU_calc: 0.4159 - val_accuracy: 0.0852
# Epoch 43/50
# 595/595 [==============================] - 40s 67ms/step - loss: 0.5868 - IOU_calc: 0.4169 - accuracy: 0.0725 - val_loss: 0.5796 - val_IOU_calc: 0.4134 - val_accuracy: 0.0823
# Epoch 44/50
# 595/595 [==============================] - 41s 68ms/step - loss: 0.5863 - IOU_calc: 0.4174 - accuracy: 0.0725 - val_loss: 0.5780 - val_IOU_calc: 0.4182 - val_accuracy: 0.0831
# Epoch 45/50
# 595/595 [==============================] - 38s 63ms/step - loss: 0.5861 - IOU_calc: 0.4180 - accuracy: 0.0726 - val_loss: 0.5770 - val_IOU_calc: 0.4151 - val_accuracy: 0.0848
# Epoch 46/50
# 595/595 [==============================] - 39s 66ms/step - loss: 0.5857 - IOU_calc: 0.4184 - accuracy: 0.0726 - val_loss: 0.5783 - val_IOU_calc: 0.4181 - val_accuracy: 0.0811
# Epoch 47/50
# 595/595 [==============================] - 37s 63ms/step - loss: 0.5853 - IOU_calc: 0.4190 - accuracy: 0.0726 - val_loss: 0.5770 - val_IOU_calc: 0.4191 - val_accuracy: 0.0853
# Epoch 48/50
# 595/595 [==============================] - 40s 66ms/step - loss: 0.5851 - IOU_calc: 0.4194 - accuracy: 0.0726 - val_loss: 0.5788 - val_IOU_calc: 0.4227 - val_accuracy: 0.0820
# Epoch 49/50
# 595/595 [==============================] - 39s 66ms/step - loss: 0.5848 - IOU_calc: 0.4199 - accuracy: 0.0726 - val_loss: 0.5773 - val_IOU_calc: 0.4163 - val_accuracy: 0.0829
# Epoch 50/50
# 595/595 [==============================] - 38s 64ms/step - loss: 0.5844 - IOU_calc: 0.4204 - accuracy: 0.0726 - val_loss: 0.5766 - val_IOU_calc: 0.4177 - val_accuracy: 0.0829

# %%
testing_gen = TrainAugmentGenerator()
#testing_gen = ValAugmentGenerator()

# %%
### Test on last frames of data

batch_img,batch_mask = next(testing_gen)
pred_all= model.predict(batch_img)
np.shape(pred_all)
# Out:
# Found 2975 images belonging to 1 classes.
# Found 2975 images belonging to 1 classes.

# %%
batch_mask[0]

# %%
for i in range(0,np.shape(pred_all)[0]):
    fig = plt.figure()
    fig.add_subplot(1,3,1)
    plt.imshow(batch_img[i])
    fig.add_subplot(1,3,2)
    plt.imshow(pred_all[i])
    fig.add_subplot(1,3,3)
    plt.imshow(batch_mask[i])
    plt.show()

# %%
model.save_weights("model_initial_20_epochs.h5", overwrite=True)
