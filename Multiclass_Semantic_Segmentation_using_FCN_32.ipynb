# %% [markdown]
# # Multiclass Semantic Segmentation using CamVid dataset

# %% [markdown]
# ## Introduction
# - Semantic Segmentation of an image is to assign each pixel in the input image a semantic class in order to get a pixel-wise dense classification.
# - A general semantic segmentation architecture can be broadly thought of as an encoder network followed by a decoder network. - - The encoder is usually is a pre-trained classification network like VGG/ResNet followed by a decoder network. The decoder network/mechanism is mostly where these architectures differ.
# - The task of the decoder is to semantically project the discriminative features (lower resolution) learnt by the encoder onto the pixel space (higher resolution) to get a dense classification. (mechanisms like skip connections, pyramid pooling etc are used for this)

# %% [markdown]
# ## Importing libraries

# %%
#!pip install tensorflow-gpu==2.0.0-alpha0

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image


import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Environment checks

# %%
print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))
# Out:
# Is there a GPU available:
# True
# Is the Tensor on GPU #0:
# True
# Device name: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(tf.executing_eagerly())
# Out:
# True

# %%
setup_data = 0

# %%
import shutil


## Try to remove tree; if failed show an error using try...except on screen
#shutil.rmtree("data/CamSeq01/train_frames")
#shutil.rmtree("data/CamSeq01/train_masks")
#shutil.rmtree("data/CamSeq01/val_frames")
#shutil.rmtree("data/CamSeq01/val_masks")

# %%
if setup_data == 1:
  # !wget http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamSeq01/CamSeq01.zip

# %%
if setup_data == 1:
  # !mkdir data
  # !mkdir data/CamSeq01

# %%
if setup_data == 1:
  # !unzip CamSeq01.zip -d data/CamSeq01

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Function to import and process frames and masks as tensors

# %%
def _read_to_tensor(fname, output_height=224, output_width=224, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    
    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %% [markdown]
# ### Image directory and size parameters

# %%
img_dir = 'data/CamSeq01/'

# Required image dimensions
output_height = 224
output_width = 224

# %% [markdown]
# ### Reading frames and masks
# - Mask file names end in "\_L.png"

# %%
def read_images(img_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - file directory
        Outputs 
            frame_tensors, masks_tensors, frame files list, mask files list
    '''
    
    # Get the file names list from provided directory
    file_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    
    # Separate frame and mask files lists, exclude unnecessary files
    frames_list = [file for file in file_list if ('_L' not in file) and ('txt' not in file)]
    masks_list = [file for file in file_list if ('_L' in file) and ('txt' not in file)]
    
    frames_list.sort()
    masks_list.sort()
    
    print('{} frame files found in the provided directory.'.format(len(frames_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    
    # Create file paths from file names
    frames_paths = [os.path.join(img_dir, fname) for fname in frames_list]
    masks_paths = [os.path.join(img_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    frame_data = tf.data.Dataset.from_tensor_slices(frames_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    frame_tensors = frame_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} frame images from the provided directory.'.format(len(frames_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))
    
    return frame_tensors, masks_tensors, frames_list, masks_list

frame_tensors, masks_tensors, frames_list, masks_list = read_images(img_dir)
# Out:
# 100 frame files found in the provided directory.
# 100 mask files found in the provided directory.
# Completed importing 100 frame images from the provided directory.
# Completed importing 100 mask images from the provided directory.

# %% [markdown]
# ### Displaying Images in the train dataset

# %%
# Make an iterator to extract images from the tensor dataset

frame_batches = tf.compat.v1.data.make_one_shot_iterator(frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks_tensors)

n_images_to_show = 5

for i in range(n_images_to_show):
    
    # Get the next image from iterator
    frame = frame_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    
    #Plot the corresponding frames and masks
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.grid(b=None)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.grid(b=None)
    plt.imshow(mask)
    plt.show()

# %% [markdown]
# ### Creating folder structure common for Computer Vision problems

# %%
DATA_PATH = 'data/CamSeq01/'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
def generate_image_folder_structure(frames, masks, frames_list, masks_list):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            frames - frame tensor dataset
            masks - mask tensor dataset
            frames_list - frame file paths
            masks_list - mask file paths
    '''
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the frames and masks in appropriate folders
    dir_name='train'
    for file in zip(frames_list[:-round(0.2*len(frames_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    #Iterate over the val images while saving the frames and masks in appropriate folders
    dir_name='val'
    for file in zip(frames_list[-round(0.2*len(frames_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    print("Saved {} frames to directory {}".format(len(frames_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
generate_image_folder_structure(frame_tensors, masks_tensors, frames_list, masks_list)

#generate_image_folder_structure(train_frames, train_masks, val_files, 'val')
# Out:
# Saved 100 frames to directory data/CamSeq01/
# Saved 100 masks to directory data/CamSeq01/

# %% [markdown]
# ## Extract Target Class definitions

# %% [markdown]
# ### Function to parse the file "label_colors.txt" which contains the class definitions

# %%
def parse_code(l):
    '''Function to parse lines in a text file, returns separated elements (label codes and names in this case)
    '''
    if len(l.strip().split("\t")) == 2:
        a, b = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), b
    else:
        a, b, c = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), c

# %% [markdown]
# ### Parse and extract label names and codes

# %%
label_codes, label_names = zip(*[parse_code(l) for l in open(img_dir+"label_colors.txt")])
label_codes, label_names = list(label_codes), list(label_names)
label_codes[:5], label_names[:5]
# Out:
# ([(64, 128, 64), (192, 0, 128), (0, 128, 192), (0, 128, 64), (128, 0, 0)],
#  ['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building'])

# %%
label_codes, label_names
# Out:
# ([(64, 128, 64),
#   (192, 0, 128),
#   (0, 128, 192),
#   (0, 128, 64),
#   (128, 0, 0),
#   (64, 0, 128),
#   (64, 0, 192),
#   (192, 128, 64),
#   (192, 192, 128),
#   (64, 64, 128),
#   (128, 0, 192),
#   (192, 0, 64),
#   (128, 128, 64),
#   (192, 0, 192),
#   (128, 64, 64),
#   (64, 192, 128),
#   (64, 64, 0),
#   (128, 64, 128),
#   (128, 128, 192),
#   (0, 0, 192),
#   (192, 128, 128),
#   (128, 128, 128),
#   (64, 128, 192),
#   (0, 0, 64),
#   (0, 64, 64),
#   (192, 64, 128),
#   (128, 128, 0),
#   (192, 128, 192),
#   (64, 0, 64),
#   (192, 192, 0),
#   (0, 0, 0),
#   (64, 192, 0)],
#  ['Animal',
#   'Archway',
#   'Bicyclist',
#   'Bridge',
#   'Building',
#   'Car',
#   'CartLuggagePram',
#   'Child',
#   'Column_Pole',
#   'Fence',
#   'LaneMkgsDriv',
#   'LaneMkgsNonDriv',
#   'Misc_Text',
#   'MotorcycleScooter',
#   'OtherMoving',
#   'ParkingBlock',
#   'Pedestrian',
#   'Road',
#   'RoadShoulder',
#   'Sidewalk',
#   'SignSymbol',
#   'Sky',
#   'SUVPickupTruck',
#   'TrafficCone',
#   'TrafficLight',
#   'Train',
#   'Tree',
#   'Truck_Bus',
#   'Tunnel',
#   'VegetationMisc',
#   'Void',
#   'Wall'])

# %% [markdown]
# ### Create useful label and code conversion dictionaries
# _These will be used for:_
# - One hot encoding the mask labels for model training
# - Decoding the predicted labels for interpretation and visualization

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (64, 128, 64),
#  1: (192, 0, 128),
#  2: (0, 128, 192),
#  3: (0, 128, 64),
#  4: (128, 0, 0),
#  5: (64, 0, 128),
#  6: (64, 0, 192),
#  7: (192, 128, 64),
#  8: (192, 192, 128),
#  9: (64, 64, 128),
#  10: (128, 0, 192),
#  11: (192, 0, 64),
#  12: (128, 128, 64),
#  13: (192, 0, 192),
#  14: (128, 64, 64),
#  15: (64, 192, 128),
#  16: (64, 64, 0),
#  17: (128, 64, 128),
#  18: (128, 128, 192),
#  19: (0, 0, 192),
#  20: (192, 128, 128),
#  21: (128, 128, 128),
#  22: (64, 128, 192),
#  23: (0, 0, 64),
#  24: (0, 64, 64),
#  25: (192, 64, 128),
#  26: (128, 128, 0),
#  27: (192, 128, 192),
#  28: (64, 0, 64),
#  29: (192, 192, 0),
#  30: (0, 0, 0),
#  31: (64, 192, 0)}

# %%
id2name
# Out:
# {0: 'Animal',
#  1: 'Archway',
#  2: 'Bicyclist',
#  3: 'Bridge',
#  4: 'Building',
#  5: 'Car',
#  6: 'CartLuggagePram',
#  7: 'Child',
#  8: 'Column_Pole',
#  9: 'Fence',
#  10: 'LaneMkgsDriv',
#  11: 'LaneMkgsNonDriv',
#  12: 'Misc_Text',
#  13: 'MotorcycleScooter',
#  14: 'OtherMoving',
#  15: 'ParkingBlock',
#  16: 'Pedestrian',
#  17: 'Road',
#  18: 'RoadShoulder',
#  19: 'Sidewalk',
#  20: 'SignSymbol',
#  21: 'Sky',
#  22: 'SUVPickupTruck',
#  23: 'TrafficCone',
#  24: 'TrafficLight',
#  25: 'Train',
#  26: 'Tree',
#  27: 'Truck_Bus',
#  28: 'Tunnel',
#  29: 'VegetationMisc',
#  30: 'Void',
#  31: 'Wall'}

# %% [markdown]
# ### Define functions for one hot encoding rgb labels, and decoding encoded predictions

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# # Creating custom Image data generators

# %% [markdown]
# ### Defining data generators

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %% [markdown]
# ### Custom image data generators for creating batches of frames and masks

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 5):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
    DATA_PATH + 'train_frames/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))

    train_mask_generator = train_masks_datagen.flow_from_directory(
    DATA_PATH + 'train_masks/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(seed = 1, batch_size = 5):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
    DATA_PATH + 'val_frames/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))


    val_mask_generator = val_masks_datagen.flow_from_directory(
    DATA_PATH + 'val_masks/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %% [markdown]
# # Defining FCN-32 model for semantic segmentation
# <b>FCN-32 Architecture</b>
#
# <div style="text-align: center;">
#
#         <img src="http://deeplearning.net/tutorial/_images/fcn.png" alt="FCN-32"U height="600" width="800">
# </div>
#
# [Picture Credits](http://deeplearning.net/tutorial/fcn_2D_segm.html)<br><br>

# %%
from tqdm import tqdm

# %%
from tqdm import tqdm_gui

# %%
os.getcwd()
# Out:
# '/content'

# %%
#os.getcwd()
#!mkdir pretrained_weights

# %%
#!wget -O pretrained_weights/vgg16_weights_tf_dim_ordering_tf_kernels.h5  https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %% [markdown]
# ### Function to create FCN-32 model, using VGG-16 pre-trained weights

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *


import os

VGG_Weights_path = "pretrained_weights/vgg16_weights_tf_dim_ordering_tf_kernels.h5"

IMAGE_ORDERING = 'channels_last'


def FCN32( n_classes ,  input_height=224, input_width=224 , vgg_level=3):

    assert input_height%32 == 0
    assert input_width%32 == 0

    # https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_th_dim_ordering_th_kernels.h5
    img_input = Input(shape=(input_height,input_width,3))

    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    f3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)
    f4 = x

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)
    f5 = x

    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1')(x)
    x = Dense(4096, activation='relu', name='fc2')(x)
    x = Dense( 1000 , activation='softmax', name='predictions')(x)

    vgg  = Model(  img_input , x  )
    vgg.load_weights(VGG_Weights_path)

    o = f5

    o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    o = Dropout(0.5)(o)
    o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    o = Dropout(0.5)(o)

    o = ( Conv2D( n_classes ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    o = Conv2DTranspose( n_classes , kernel_size=(32,32) ,  strides=(32,32) , use_bias=False ,  data_format=IMAGE_ORDERING )(o)
    #o_shape = Model(img_input , o ).output_shape

    #outputHeight = o_shape[2]
    #outputWidth = o_shape[3]

    #print ("koko" , o_shape)

    #o = (Reshape(( -1  , outputHeight*outputWidth   )))(o)
    #o = (Permute((2, 1)))(o)
    o = (Activation('softmax'))(o)
    model = Model( img_input , o )
    #model.outputWidth = outputWidth
    #model.outputHeight = outputHeight

    return model

# %%
model = FCN32( 32 ,  input_height=224, input_width=224 , vgg_level=3)

# %%
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 4096)        102764544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 4096)        16781312
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 32)          131104
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 224, 224, 32)      1048576
# _________________________________________________________________
# activation_3 (Activation)    (None, 224, 224, 32)      0
# =================================================================
# Total params: 135,440,224
# Trainable params: 135,440,224
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Defining twerky loss and dice co-efficients for model performance

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
smooth = 1.

# %% [markdown]
# ## Compiling model
# - Using categorical crossentropy loss since labels have been one hot encoded

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[tversky_loss,dice_coef,'accuracy'])

# %%
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 4096)        102764544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 4096)        16781312
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 32)          131104
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 224, 224, 32)      1048576
# _________________________________________________________________
# activation_3 (Activation)    (None, 224, 224, 32)      0
# =================================================================
# Total params: 135,440,224
# Trainable params: 135,440,224
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.load_weights("model_100_epochs.h5")

# %% [markdown]
# ## Define model callback settings

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='camvid_model_FCN32_checkpoint.h5', monitor='accuracy', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_accuracy', patience=50, verbose=1)
callbacks = [tb, mc, es]

# %% [markdown]
# ## Train and save the U-Net model

# %%
batch_size = 5
steps_per_epoch = np.ceil(float(len(frames_list) - round(0.2*len(frames_list))) / float(batch_size))
steps_per_epoch
# Out:
# 16.0

# %%
validation_steps = (float((round(0.2*len(frames_list)))) / float(batch_size))
validation_steps
# Out:
# 4.0

# %%
num_epochs = 100

# %%
# Train model

batch_size = 5
result = model.fit_generator(TrainAugmentGenerator(), steps_per_epoch=steps_per_epoch ,
                validation_data = ValAugmentGenerator(), 
                validation_steps = validation_steps, epochs=num_epochs, callbacks=callbacks,
use_multiprocessing=False, verbose=1)
model.save_weights("camvid_model_FCN32.h5", overwrite=True)
# Out:
# Found 80 images belonging to 1 classes.
# Epoch 1/100
# Found 80 images belonging to 1 classes.
# 15/16 [===========================>..] - ETA: 1s - loss: 3.2017 - tversky_loss: 31.7110 - dice_coef: 0.3937 - accuracy: 0.3981Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
#
# Epoch 00001: accuracy improved from -inf to 0.41439, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 31s 2s/step - loss: 3.0742 - tversky_loss: 31.6924 - dice_coef: 0.4137 - accuracy: 0.4144 - val_loss: 1.2196 - val_tversky_loss: 31.4579 - val_dice_coef: 0.6887 - val_accuracy: 0.6356
# Epoch 2/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9107 - tversky_loss: 31.4004 - dice_coef: 0.7517 - accuracy: 0.7016
# Epoch 00002: accuracy improved from 0.41439 to 0.70712, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.8941 - tversky_loss: 31.3936 - dice_coef: 0.7569 - accuracy: 0.7071 - val_loss: 1.3418 - val_tversky_loss: 31.4401 - val_dice_coef: 0.6609 - val_accuracy: 0.5840
# Epoch 3/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.7194 - tversky_loss: 31.3271 - dice_coef: 0.8074 - accuracy: 0.7603
# Epoch 00003: accuracy improved from 0.70712 to 0.75976, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.7204 - tversky_loss: 31.3285 - dice_coef: 0.8068 - accuracy: 0.7598 - val_loss: 0.9173 - val_tversky_loss: 31.3863 - val_dice_coef: 0.7485 - val_accuracy: 0.6971
# Epoch 4/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6044 - tversky_loss: 31.2820 - dice_coef: 0.8376 - accuracy: 0.7933
# Epoch 00004: accuracy improved from 0.75976 to 0.79531, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.5979 - tversky_loss: 31.2802 - dice_coef: 0.8392 - accuracy: 0.7953 - val_loss: 0.8870 - val_tversky_loss: 31.3517 - val_dice_coef: 0.7737 - val_accuracy: 0.7293
# Epoch 5/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5240 - tversky_loss: 31.2514 - dice_coef: 0.8554 - accuracy: 0.8125
# Epoch 00005: accuracy improved from 0.79531 to 0.81097, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.5278 - tversky_loss: 31.2521 - dice_coef: 0.8544 - accuracy: 0.8110 - val_loss: 0.8081 - val_tversky_loss: 31.3287 - val_dice_coef: 0.8001 - val_accuracy: 0.7576
# Epoch 6/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4763 - tversky_loss: 31.2361 - dice_coef: 0.8669 - accuracy: 0.8256
# Epoch 00006: accuracy improved from 0.81097 to 0.82286, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.4822 - tversky_loss: 31.2387 - dice_coef: 0.8649 - accuracy: 0.8229 - val_loss: 0.6917 - val_tversky_loss: 31.2963 - val_dice_coef: 0.8237 - val_accuracy: 0.7791
# Epoch 7/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.4402 - tversky_loss: 31.2210 - dice_coef: 0.8754 - accuracy: 0.8333
# Epoch 00007: accuracy improved from 0.82286 to 0.83312, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.4415 - tversky_loss: 31.2215 - dice_coef: 0.8751 - accuracy: 0.8331 - val_loss: 0.6416 - val_tversky_loss: 31.2790 - val_dice_coef: 0.8356 - val_accuracy: 0.7974
# Epoch 8/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.4221 - tversky_loss: 31.2156 - dice_coef: 0.8788 - accuracy: 0.8380
# Epoch 00008: accuracy improved from 0.83312 to 0.83854, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.4204 - tversky_loss: 31.2142 - dice_coef: 0.8793 - accuracy: 0.8385 - val_loss: 0.6889 - val_tversky_loss: 31.2634 - val_dice_coef: 0.8352 - val_accuracy: 0.7934
# Epoch 9/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3959 - tversky_loss: 31.2042 - dice_coef: 0.8849 - accuracy: 0.8433
# Epoch 00009: accuracy improved from 0.83854 to 0.84211, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3991 - tversky_loss: 31.2047 - dice_coef: 0.8838 - accuracy: 0.8421 - val_loss: 0.6476 - val_tversky_loss: 31.2639 - val_dice_coef: 0.8351 - val_accuracy: 0.7893
# Epoch 10/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3937 - tversky_loss: 31.2047 - dice_coef: 0.8848 - accuracy: 0.8442
# Epoch 00010: accuracy improved from 0.84211 to 0.84448, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3925 - tversky_loss: 31.2044 - dice_coef: 0.8850 - accuracy: 0.8445 - val_loss: 0.7150 - val_tversky_loss: 31.2719 - val_dice_coef: 0.8310 - val_accuracy: 0.7889
# Epoch 11/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3620 - tversky_loss: 31.1912 - dice_coef: 0.8929 - accuracy: 0.8534
# Epoch 00011: accuracy improved from 0.84448 to 0.85428, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3596 - tversky_loss: 31.1905 - dice_coef: 0.8936 - accuracy: 0.8543 - val_loss: 0.7368 - val_tversky_loss: 31.2522 - val_dice_coef: 0.8316 - val_accuracy: 0.7904
# Epoch 12/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3395 - tversky_loss: 31.1824 - dice_coef: 0.8983 - accuracy: 0.8597
# Epoch 00012: accuracy improved from 0.85428 to 0.85904, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3411 - tversky_loss: 31.1830 - dice_coef: 0.8978 - accuracy: 0.8590 - val_loss: 0.8732 - val_tversky_loss: 31.2679 - val_dice_coef: 0.8152 - val_accuracy: 0.7789
# Epoch 13/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3318 - tversky_loss: 31.1790 - dice_coef: 0.9003 - accuracy: 0.8626
# Epoch 00013: accuracy improved from 0.85904 to 0.86253, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.3324 - tversky_loss: 31.1785 - dice_coef: 0.9002 - accuracy: 0.8625 - val_loss: 0.8104 - val_tversky_loss: 31.2470 - val_dice_coef: 0.8262 - val_accuracy: 0.7824
# Epoch 14/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3173 - tversky_loss: 31.1717 - dice_coef: 0.9041 - accuracy: 0.8670
# Epoch 00014: accuracy improved from 0.86253 to 0.86632, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3188 - tversky_loss: 31.1721 - dice_coef: 0.9036 - accuracy: 0.8663 - val_loss: 0.8658 - val_tversky_loss: 31.2568 - val_dice_coef: 0.8188 - val_accuracy: 0.7789
# Epoch 15/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3004 - tversky_loss: 31.1653 - dice_coef: 0.9082 - accuracy: 0.8711
# Epoch 00015: accuracy improved from 0.86632 to 0.87068, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.3021 - tversky_loss: 31.1657 - dice_coef: 0.9078 - accuracy: 0.8707 - val_loss: 0.8136 - val_tversky_loss: 31.2682 - val_dice_coef: 0.8157 - val_accuracy: 0.7744
# Epoch 16/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2954 - tversky_loss: 31.1630 - dice_coef: 0.9087 - accuracy: 0.8714
# Epoch 00016: accuracy improved from 0.87068 to 0.87208, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2945 - tversky_loss: 31.1624 - dice_coef: 0.9093 - accuracy: 0.8721 - val_loss: 0.8473 - val_tversky_loss: 31.2706 - val_dice_coef: 0.8136 - val_accuracy: 0.7714
# Epoch 17/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2836 - tversky_loss: 31.1585 - dice_coef: 0.9119 - accuracy: 0.8750
# Epoch 00017: accuracy improved from 0.87208 to 0.87596, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2817 - tversky_loss: 31.1569 - dice_coef: 0.9126 - accuracy: 0.8760 - val_loss: 0.8372 - val_tversky_loss: 31.2547 - val_dice_coef: 0.8192 - val_accuracy: 0.7745
# Epoch 18/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2734 - tversky_loss: 31.1544 - dice_coef: 0.9146 - accuracy: 0.8779
# Epoch 00018: accuracy improved from 0.87596 to 0.87841, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2723 - tversky_loss: 31.1537 - dice_coef: 0.9150 - accuracy: 0.8784 - val_loss: 0.7728 - val_tversky_loss: 31.2434 - val_dice_coef: 0.8306 - val_accuracy: 0.7833
# Epoch 19/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2657 - tversky_loss: 31.1506 - dice_coef: 0.9165 - accuracy: 0.8803
# Epoch 00019: accuracy improved from 0.87841 to 0.88057, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2651 - tversky_loss: 31.1500 - dice_coef: 0.9167 - accuracy: 0.8806 - val_loss: 0.8508 - val_tversky_loss: 31.2405 - val_dice_coef: 0.8260 - val_accuracy: 0.7836
# Epoch 20/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2607 - tversky_loss: 31.1476 - dice_coef: 0.9177 - accuracy: 0.8817
# Epoch 00020: accuracy improved from 0.88057 to 0.88095, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2622 - tversky_loss: 31.1481 - dice_coef: 0.9172 - accuracy: 0.8810 - val_loss: 0.8434 - val_tversky_loss: 31.2396 - val_dice_coef: 0.8301 - val_accuracy: 0.7899
# Epoch 21/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2541 - tversky_loss: 31.1452 - dice_coef: 0.9188 - accuracy: 0.8823
# Epoch 00021: accuracy improved from 0.88095 to 0.88278, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2529 - tversky_loss: 31.1446 - dice_coef: 0.9191 - accuracy: 0.8828 - val_loss: 0.8291 - val_tversky_loss: 31.2457 - val_dice_coef: 0.8275 - val_accuracy: 0.7847
# Epoch 22/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2450 - tversky_loss: 31.1414 - dice_coef: 0.9220 - accuracy: 0.8867
# Epoch 00022: accuracy improved from 0.88278 to 0.88564, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2472 - tversky_loss: 31.1428 - dice_coef: 0.9212 - accuracy: 0.8856 - val_loss: 0.8627 - val_tversky_loss: 31.2427 - val_dice_coef: 0.8249 - val_accuracy: 0.7843
# Epoch 23/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2397 - tversky_loss: 31.1381 - dice_coef: 0.9230 - accuracy: 0.8874
# Epoch 00023: accuracy improved from 0.88564 to 0.88689, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2414 - tversky_loss: 31.1390 - dice_coef: 0.9225 - accuracy: 0.8869 - val_loss: 0.8523 - val_tversky_loss: 31.2471 - val_dice_coef: 0.8216 - val_accuracy: 0.7769
# Epoch 24/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2339 - tversky_loss: 31.1362 - dice_coef: 0.9241 - accuracy: 0.8884
# Epoch 00024: accuracy improved from 0.88689 to 0.88789, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2349 - tversky_loss: 31.1369 - dice_coef: 0.9238 - accuracy: 0.8879 - val_loss: 0.8656 - val_tversky_loss: 31.2467 - val_dice_coef: 0.8223 - val_accuracy: 0.7797
# Epoch 25/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2320 - tversky_loss: 31.1353 - dice_coef: 0.9245 - accuracy: 0.8893
# Epoch 00025: accuracy improved from 0.88789 to 0.88890, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2327 - tversky_loss: 31.1361 - dice_coef: 0.9243 - accuracy: 0.8889 - val_loss: 0.8569 - val_tversky_loss: 31.2505 - val_dice_coef: 0.8229 - val_accuracy: 0.7806
# Epoch 26/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.2249 - tversky_loss: 31.1323 - dice_coef: 0.9265 - accuracy: 0.8912
# Epoch 00026: accuracy improved from 0.88890 to 0.89084, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2259 - tversky_loss: 31.1329 - dice_coef: 0.9262 - accuracy: 0.8908 - val_loss: 0.8694 - val_tversky_loss: 31.2443 - val_dice_coef: 0.8229 - val_accuracy: 0.7840
# Epoch 27/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2251 - tversky_loss: 31.1323 - dice_coef: 0.9263 - accuracy: 0.8911
# Epoch 00027: accuracy improved from 0.89084 to 0.89175, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2233 - tversky_loss: 31.1315 - dice_coef: 0.9268 - accuracy: 0.8918 - val_loss: 0.8085 - val_tversky_loss: 31.2313 - val_dice_coef: 0.8346 - val_accuracy: 0.7910
# Epoch 28/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2177 - tversky_loss: 31.1287 - dice_coef: 0.9283 - accuracy: 0.8933
# Epoch 00028: accuracy improved from 0.89175 to 0.89391, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.2165 - tversky_loss: 31.1281 - dice_coef: 0.9287 - accuracy: 0.8939 - val_loss: 0.8076 - val_tversky_loss: 31.2363 - val_dice_coef: 0.8302 - val_accuracy: 0.7867
# Epoch 29/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2188 - tversky_loss: 31.1301 - dice_coef: 0.9276 - accuracy: 0.8924
# Epoch 00029: accuracy did not improve from 0.89391
# 16/16 [==============================] - 18s 1s/step - loss: 0.2181 - tversky_loss: 31.1297 - dice_coef: 0.9280 - accuracy: 0.8928 - val_loss: 0.9964 - val_tversky_loss: 31.2511 - val_dice_coef: 0.8126 - val_accuracy: 0.7751
# Epoch 30/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2130 - tversky_loss: 31.1270 - dice_coef: 0.9291 - accuracy: 0.8944
# Epoch 00030: accuracy improved from 0.89391 to 0.89505, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.2118 - tversky_loss: 31.1265 - dice_coef: 0.9295 - accuracy: 0.8950 - val_loss: 0.9147 - val_tversky_loss: 31.2480 - val_dice_coef: 0.8218 - val_accuracy: 0.7832
# Epoch 31/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2077 - tversky_loss: 31.1244 - dice_coef: 0.9305 - accuracy: 0.8960
# Epoch 00031: accuracy improved from 0.89505 to 0.89578, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.2089 - tversky_loss: 31.1245 - dice_coef: 0.9303 - accuracy: 0.8958 - val_loss: 0.8779 - val_tversky_loss: 31.2447 - val_dice_coef: 0.8193 - val_accuracy: 0.7745
# Epoch 32/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.2044 - tversky_loss: 31.1219 - dice_coef: 0.9314 - accuracy: 0.8972
# Epoch 00032: accuracy improved from 0.89578 to 0.89722, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.2044 - tversky_loss: 31.1220 - dice_coef: 0.9315 - accuracy: 0.8972 - val_loss: 0.8791 - val_tversky_loss: 31.2459 - val_dice_coef: 0.8255 - val_accuracy: 0.7878
# Epoch 33/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2005 - tversky_loss: 31.1213 - dice_coef: 0.9328 - accuracy: 0.8990
# Epoch 00033: accuracy improved from 0.89722 to 0.89819, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.2021 - tversky_loss: 31.1224 - dice_coef: 0.9322 - accuracy: 0.8982 - val_loss: 0.8169 - val_tversky_loss: 31.2479 - val_dice_coef: 0.8258 - val_accuracy: 0.7835
# Epoch 34/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1951 - tversky_loss: 31.1183 - dice_coef: 0.9341 - accuracy: 0.9003
# Epoch 00034: accuracy improved from 0.89819 to 0.90030, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.1952 - tversky_loss: 31.1186 - dice_coef: 0.9341 - accuracy: 0.9003 - val_loss: 0.8867 - val_tversky_loss: 31.2442 - val_dice_coef: 0.8240 - val_accuracy: 0.7861
# Epoch 35/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1890 - tversky_loss: 31.1157 - dice_coef: 0.9356 - accuracy: 0.9019
# Epoch 00035: accuracy improved from 0.90030 to 0.90171, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1895 - tversky_loss: 31.1159 - dice_coef: 0.9354 - accuracy: 0.9017 - val_loss: 0.8157 - val_tversky_loss: 31.2294 - val_dice_coef: 0.8354 - val_accuracy: 0.7943
# Epoch 36/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1863 - tversky_loss: 31.1141 - dice_coef: 0.9364 - accuracy: 0.9032
# Epoch 00036: accuracy improved from 0.90171 to 0.90312, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.1861 - tversky_loss: 31.1144 - dice_coef: 0.9364 - accuracy: 0.9031 - val_loss: 0.9028 - val_tversky_loss: 31.2592 - val_dice_coef: 0.8156 - val_accuracy: 0.7767
# Epoch 37/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1837 - tversky_loss: 31.1137 - dice_coef: 0.9370 - accuracy: 0.9038
# Epoch 00037: accuracy improved from 0.90312 to 0.90313, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.1853 - tversky_loss: 31.1143 - dice_coef: 0.9365 - accuracy: 0.9031 - val_loss: 0.9039 - val_tversky_loss: 31.2315 - val_dice_coef: 0.8279 - val_accuracy: 0.7903
# Epoch 38/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1810 - tversky_loss: 31.1119 - dice_coef: 0.9372 - accuracy: 0.9041
# Epoch 00038: accuracy improved from 0.90313 to 0.90429, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1807 - tversky_loss: 31.1116 - dice_coef: 0.9375 - accuracy: 0.9043 - val_loss: 0.8382 - val_tversky_loss: 31.2449 - val_dice_coef: 0.8250 - val_accuracy: 0.7839
# Epoch 39/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1802 - tversky_loss: 31.1121 - dice_coef: 0.9377 - accuracy: 0.9043
# Epoch 00039: accuracy improved from 0.90429 to 0.90448, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1797 - tversky_loss: 31.1121 - dice_coef: 0.9379 - accuracy: 0.9045 - val_loss: 0.8606 - val_tversky_loss: 31.2523 - val_dice_coef: 0.8236 - val_accuracy: 0.7830
# Epoch 40/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1765 - tversky_loss: 31.1095 - dice_coef: 0.9389 - accuracy: 0.9060
# Epoch 00040: accuracy improved from 0.90448 to 0.90554, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1775 - tversky_loss: 31.1100 - dice_coef: 0.9386 - accuracy: 0.9055 - val_loss: 0.8918 - val_tversky_loss: 31.2481 - val_dice_coef: 0.8188 - val_accuracy: 0.7788
# Epoch 41/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1759 - tversky_loss: 31.1094 - dice_coef: 0.9387 - accuracy: 0.9055
# Epoch 00041: accuracy improved from 0.90554 to 0.90610, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1750 - tversky_loss: 31.1085 - dice_coef: 0.9391 - accuracy: 0.9061 - val_loss: 0.9080 - val_tversky_loss: 31.2575 - val_dice_coef: 0.8164 - val_accuracy: 0.7778
# Epoch 42/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1726 - tversky_loss: 31.1087 - dice_coef: 0.9397 - accuracy: 0.9068
# Epoch 00042: accuracy improved from 0.90610 to 0.90714, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1717 - tversky_loss: 31.1080 - dice_coef: 0.9399 - accuracy: 0.9071 - val_loss: 0.9705 - val_tversky_loss: 31.2475 - val_dice_coef: 0.8147 - val_accuracy: 0.7777
# Epoch 43/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1698 - tversky_loss: 31.1071 - dice_coef: 0.9403 - accuracy: 0.9072
# Epoch 00043: accuracy improved from 0.90714 to 0.90756, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1692 - tversky_loss: 31.1068 - dice_coef: 0.9406 - accuracy: 0.9076 - val_loss: 0.8444 - val_tversky_loss: 31.2382 - val_dice_coef: 0.8272 - val_accuracy: 0.7848
# Epoch 44/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1660 - tversky_loss: 31.1051 - dice_coef: 0.9413 - accuracy: 0.9084
# Epoch 00044: accuracy improved from 0.90756 to 0.90838, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1663 - tversky_loss: 31.1050 - dice_coef: 0.9412 - accuracy: 0.9084 - val_loss: 0.9071 - val_tversky_loss: 31.2512 - val_dice_coef: 0.8199 - val_accuracy: 0.7819
# Epoch 45/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.1622 - tversky_loss: 31.1030 - dice_coef: 0.9425 - accuracy: 0.9103
# Epoch 00045: accuracy improved from 0.90838 to 0.90938, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.1645 - tversky_loss: 31.1041 - dice_coef: 0.9418 - accuracy: 0.9094 - val_loss: 0.9106 - val_tversky_loss: 31.2621 - val_dice_coef: 0.8158 - val_accuracy: 0.7765
# Epoch 46/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1636 - tversky_loss: 31.1036 - dice_coef: 0.9421 - accuracy: 0.9096
# Epoch 00046: accuracy improved from 0.90938 to 0.90979, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1630 - tversky_loss: 31.1034 - dice_coef: 0.9423 - accuracy: 0.9098 - val_loss: 0.8562 - val_tversky_loss: 31.2257 - val_dice_coef: 0.8328 - val_accuracy: 0.7936
# Epoch 47/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1561 - tversky_loss: 31.1001 - dice_coef: 0.9442 - accuracy: 0.9124
# Epoch 00047: accuracy improved from 0.90979 to 0.91138, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1586 - tversky_loss: 31.1014 - dice_coef: 0.9434 - accuracy: 0.9114 - val_loss: 0.9285 - val_tversky_loss: 31.2434 - val_dice_coef: 0.8235 - val_accuracy: 0.7856
# Epoch 48/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1593 - tversky_loss: 31.1012 - dice_coef: 0.9430 - accuracy: 0.9107
# Epoch 00048: accuracy did not improve from 0.91138
# 16/16 [==============================] - 18s 1s/step - loss: 0.1628 - tversky_loss: 31.1029 - dice_coef: 0.9420 - accuracy: 0.9096 - val_loss: 0.8232 - val_tversky_loss: 31.2586 - val_dice_coef: 0.8238 - val_accuracy: 0.7834
# Epoch 49/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1617 - tversky_loss: 31.1031 - dice_coef: 0.9424 - accuracy: 0.9100
# Epoch 00049: accuracy did not improve from 0.91138
# 16/16 [==============================] - 18s 1s/step - loss: 0.1611 - tversky_loss: 31.1027 - dice_coef: 0.9427 - accuracy: 0.9104 - val_loss: 0.8462 - val_tversky_loss: 31.2407 - val_dice_coef: 0.8295 - val_accuracy: 0.7884
# Epoch 50/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1507 - tversky_loss: 31.0972 - dice_coef: 0.9457 - accuracy: 0.9138
# Epoch 00050: accuracy improved from 0.91138 to 0.91195, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 20s 1s/step - loss: 0.1548 - tversky_loss: 31.0993 - dice_coef: 0.9443 - accuracy: 0.9119 - val_loss: 0.9283 - val_tversky_loss: 31.2572 - val_dice_coef: 0.8144 - val_accuracy: 0.7762
# Epoch 51/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1519 - tversky_loss: 31.0990 - dice_coef: 0.9448 - accuracy: 0.9128
# Epoch 00051: accuracy improved from 0.91195 to 0.91376, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1499 - tversky_loss: 31.0979 - dice_coef: 0.9456 - accuracy: 0.9138 - val_loss: 0.8647 - val_tversky_loss: 31.2435 - val_dice_coef: 0.8280 - val_accuracy: 0.7887
# Epoch 52/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1509 - tversky_loss: 31.0970 - dice_coef: 0.9451 - accuracy: 0.9132
# Epoch 00052: accuracy did not improve from 0.91376
# 16/16 [==============================] - 18s 1s/step - loss: 0.1500 - tversky_loss: 31.0965 - dice_coef: 0.9455 - accuracy: 0.9137 - val_loss: 0.9286 - val_tversky_loss: 31.2504 - val_dice_coef: 0.8172 - val_accuracy: 0.7802
# Epoch 53/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1479 - tversky_loss: 31.0957 - dice_coef: 0.9464 - accuracy: 0.9149
# Epoch 00053: accuracy improved from 0.91376 to 0.91478, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1481 - tversky_loss: 31.0958 - dice_coef: 0.9463 - accuracy: 0.9148 - val_loss: 0.8730 - val_tversky_loss: 31.2381 - val_dice_coef: 0.8291 - val_accuracy: 0.7916
# Epoch 54/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1437 - tversky_loss: 31.0944 - dice_coef: 0.9473 - accuracy: 0.9159
# Epoch 00054: accuracy improved from 0.91478 to 0.91577, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1441 - tversky_loss: 31.0947 - dice_coef: 0.9472 - accuracy: 0.9158 - val_loss: 0.9960 - val_tversky_loss: 31.2618 - val_dice_coef: 0.8095 - val_accuracy: 0.7728
# Epoch 55/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1426 - tversky_loss: 31.0932 - dice_coef: 0.9475 - accuracy: 0.9160
# Epoch 00055: accuracy improved from 0.91577 to 0.91577, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1432 - tversky_loss: 31.0935 - dice_coef: 0.9473 - accuracy: 0.9158 - val_loss: 0.8796 - val_tversky_loss: 31.2385 - val_dice_coef: 0.8267 - val_accuracy: 0.7882
# Epoch 56/100
# 15/16 [===========================>..] - ETA: 1s - loss: 0.1440 - tversky_loss: 31.0940 - dice_coef: 0.9472 - accuracy: 0.9158
# Epoch 00056: accuracy did not improve from 0.91577
# 16/16 [==============================] - 18s 1s/step - loss: 0.1445 - tversky_loss: 31.0942 - dice_coef: 0.9471 - accuracy: 0.9158 - val_loss: 0.8308 - val_tversky_loss: 31.2499 - val_dice_coef: 0.8273 - val_accuracy: 0.7878
# Epoch 57/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1428 - tversky_loss: 31.0943 - dice_coef: 0.9474 - accuracy: 0.9158
# Epoch 00057: accuracy improved from 0.91577 to 0.91651, saving model to camvid_model_FCN32_checkpoint.h5
# 16/16 [==============================] - 21s 1s/step - loss: 0.1414 - tversky_loss: 31.0933 - dice_coef: 0.9479 - accuracy: 0.9165 - val_loss: 0.8257 - val_tversky_loss: 31.2329 - val_dice_coef: 0.8332 - val_accuracy: 0.7957
# Epoch 00057: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Model evaluation historical plots

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), result.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), result.history["val_accuracy"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
#training_gen = TrainAugmentGenerator()
testing_gen = ValAugmentGenerator()

# %% [markdown]
# ### Extract and display model frame, prediction and mask batch

# %%
batch_img,batch_mask = next(testing_gen)
pred_all= model.predict(batch_img)
np.shape(pred_all)
# Out:
# Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
# (5, 224, 224, 32)

# %%
for i in range(0,np.shape(pred_all)[0]):
    
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,3,1)
    ax1.imshow(batch_img[i])
    ax1.title.set_text('Actual frame')
    ax1.grid(b=None)
    
    
    ax2 = fig.add_subplot(1,3,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(batch_mask[i],id2code))
    ax2.grid(b=None)
    
    ax3 = fig.add_subplot(1,3,3)
    ax3.set_title('Predicted labels')
    ax3.imshow(onehot_to_rgb(pred_all[i],id2code))
    ax3.grid(b=None)
    
    plt.show()
