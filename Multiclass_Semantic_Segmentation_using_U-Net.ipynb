# %% [markdown]
# # Multiclass Semantic Segmentation using CamVid dataset

# %% [markdown]
# ## Introduction
# - Semantic Segmentation of an image is to assign each pixel in the input image a semantic class in order to get a pixel-wise dense classification.
# - A general semantic segmentation architecture can be broadly thought of as an encoder network followed by a decoder network. - - The encoder is usually is a pre-trained classification network like VGG/ResNet followed by a decoder network. The decoder network/mechanism is mostly where these architectures differ.
# - The task of the decoder is to semantically project the discriminative features (lower resolution) learnt by the encoder onto the pixel space (higher resolution) to get a dense classification. (mechanisms like skip connections, pyramid pooling etc are used for this)

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image


import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Environment checks

# %%
tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 1.14.0

# %%
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Is the Tensor on GPU #1:  "),
print(x.device.endswith('GPU:1'))

print("Device name: {}".format((x.device)))
# Out:
# Is there a GPU available:
# True
# Is the Tensor on GPU #0:
# True
# Is the Tensor on GPU #1:
# False
# Device name: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(tf.executing_eagerly())
# Out:
# True

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Function to import and process frames and masks as tensors

# %%
def _read_to_tensor(fname, output_height=1120, output_width=1504, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)
    
    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %% [markdown]
# ### Image directory and size parameters

# %%
img_dir = 'data/'

# Required image dimensions
output_height = 1120
output_width = 1504

# %% [markdown]
# ### Reading frames and masks
# - Mask file names end in "\_L.png"

# %%
def read_images(img_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - file directory
        Outputs 
            frame_tensors, masks_tensors, frame files list, mask files list
    '''
    
    # Get the file names list from provided directory
    file_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    file_list.sort()
    
    # Separate frame and mask files lists, exclude unnecessary files
    frames_list = [file for file in file_list if ('png' not in file) and ('txt' not in file)]
    masks_list = [file for file in file_list if ('png' in file) and ('txt' not in file)]
    
    frames_list.sort()
    masks_list.sort()
    
    print('{} frame files found in the provided directory.'.format(len(frames_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    #print(frames_list)
    
    # Create file paths from file names
    frames_paths = [os.path.join(img_dir, fname) for fname in frames_list]
    masks_paths = [os.path.join(img_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    frame_data = tf.data.Dataset.from_tensor_slices(frames_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    frame_tensors = frame_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} frame images from the provided directory.'.format(len(frames_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))
    
    return frame_tensors, masks_tensors, frames_list, masks_list

frame_tensors, masks_tensors, frames_list, masks_list = read_images(img_dir)
# Out:
# 1522 frame files found in the provided directory.
# 1522 mask files found in the provided directory.
# Completed importing 1522 frame images from the provided directory.
# Completed importing 1522 mask images from the provided directory.

# %% [markdown]
# ### Displaying Images in the train dataset

# %%
# Make an iterator to extract images from the tensor dataset
frame_batches = tf.compat.v1.data.make_one_shot_iterator(frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks_tensors)
'''
n_images_to_show = 10

#Check Channels
#for i in range(1512):
#    frame = frame_batches.next().numpy().astype(np.uint8)
#    a,b,c = shape(frame)
#    if(c!=3):
#        print(frames_list[i],":",shape(frame)) # image with wrong channel -> edit original image by adding color
#    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frame_tensors) # init iterator to the first

# Displaying Images in the train datase
for i in range(n_images_to_show):
    
    # Get the next image from iterator
    frame =frame_batches.next().numpy().astype(np.uint8)
    mask = mask_batches.next().numpy().astype(np.uint8)
    print(i,":",shape(frame))
    #Plot the corresponding frames and masks
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.imshow(mask)
    plt.show()
'''
# Out:
# 0 : (1120, 1504, 3)
# 1 : (1120, 1504, 3)
# 2 : (1120, 1504, 3)
# 3 : (1120, 1504, 3)
# 4 : (1120, 1504, 3)
# 5 : (1120, 1504, 3)
# 6 : (1120, 1504, 3)
# 7 : (1120, 1504, 3)
# 8 : (1120, 1504, 3)
# 9 : (1120, 1504, 3)

# %% [markdown]
# ### Creating folder structure common for Computer Vision problems

# %%
DATA_PATH = 'data/CamSeq01/'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(DATA_PATH + folder)
    except Exception as e: print(e)
# Out:
# [Errno 17] File exists: 'data/CamSeq01/train_frames/train'
# [Errno 17] File exists: 'data/CamSeq01/train_masks/train'
# [Errno 17] File exists: 'data/CamSeq01/val_frames/val'
# [Errno 17] File exists: 'data/CamSeq01/val_masks/val'

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
def generate_image_folder_structure(frames, masks, frames_list, masks_list):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            frames - frame tensor dataset
            masks - mask tensor dataset
            frames_list - frame file paths
            masks_list - mask file paths
    '''
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the frames and masks in appropriate folders
    dir_name='train'
    for file in zip(frames_list[:-round(0.2*len(frames_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    #Iterate over the val images while saving the frames and masks in appropriate folders
    dir_name='val'
    for file in zip(frames_list[-round(0.2*len(frames_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        #Convert numpy arrays to images
        frame = Image.fromarray(frame)
        mask = Image.fromarray(mask)
        
        #Save frames and masks to correct directories
        frame.save(DATA_PATH+'{}_frames/{}'.format(dir_name,dir_name)+'/'+file[0])
        mask.save(DATA_PATH+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1])
    
    print("Saved {} frames to directory {}".format(len(frames_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
## If you already devided it manually, you do not need to run this.    
#generate_image_folder_structure(frame_tensors, masks_tensors, frames_list, masks_list)

#generate_image_folder_structure(train_frames, train_masks, val_files, 'val')

# %% [markdown]
# ## Extract Target Class definitions

# %% [markdown]
# ### Function to parse the file "label_colors.txt" which contains the class definitions

# %%
def parse_code(l):
    '''Function to parse lines in a text file, returns separated elements (label codes and names in this case)
    '''
    if len(l.strip().split("\t")) == 2:
        a, b = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), b
    else:
        a, b, c = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), c

# %% [markdown]
# ### Parse and extract label names and codes

# %%
label_codes = [(176,112,32),(176,240,32),(48,112,32),(112,112,32),(48,240,32),(176,240,160),(176,112,160),(48,112,160),(48,240,160),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40),(50,50,40)]
label_names = ['Cortical subplate','Hypothalamus','Cerebral nuclei','auditory area','Hippocampal formation','Thalamus','Retrosplenial area','Olfactory area','Somatosensory area','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump','dump']
label_codes[:5], label_names[:5]
# Out:
# ([(176, 112, 32),
#   (176, 240, 32),
#   (48, 112, 32),
#   (112, 112, 32),
#   (48, 240, 32)],
#  ['Cortical subplate',
#   'Hypothalamus',
#   'Cerebral nuclei',
#   'auditory area',
#   'Hippocampal formation'])

# %%
label_codes, label_names
# Out:
# ([(176, 112, 32),
#   (176, 240, 32),
#   (48, 112, 32),
#   (112, 112, 32),
#   (48, 240, 32),
#   (176, 240, 160),
#   (176, 112, 160),
#   (48, 112, 160),
#   (48, 240, 160),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4),
#   (5, 5, 4)],
#  ['Cortical subplate',
#   'Hypothalamus',
#   'Cerebral nuclei',
#   'auditory area',
#   'Hippocampal formation',
#   'Thalamus',
#   'Retrosplenial area',
#   'Olfactory area',
#   'Somatosensory area',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump',
#   'dump'])

# %% [markdown]
# ### Create useful label and code conversion dictionaries
# _These will be used for:_
# - One hot encoding the mask labels for model training
# - Decoding the predicted labels for interpretation and visualization

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (176, 112, 32),
#  1: (176, 240, 32),
#  2: (48, 112, 32),
#  3: (112, 112, 32),
#  4: (48, 240, 32),
#  5: (176, 240, 160),
#  6: (176, 112, 160),
#  7: (48, 112, 160),
#  8: (48, 240, 160),
#  9: (5, 5, 4),
#  10: (5, 5, 4),
#  11: (5, 5, 4),
#  12: (5, 5, 4),
#  13: (5, 5, 4),
#  14: (5, 5, 4),
#  15: (5, 5, 4),
#  16: (5, 5, 4),
#  17: (5, 5, 4),
#  18: (5, 5, 4),
#  19: (5, 5, 4),
#  20: (5, 5, 4),
#  21: (5, 5, 4),
#  22: (5, 5, 4),
#  23: (5, 5, 4),
#  24: (5, 5, 4),
#  25: (5, 5, 4),
#  26: (5, 5, 4),
#  27: (5, 5, 4),
#  28: (5, 5, 4),
#  29: (5, 5, 4),
#  30: (5, 5, 4),
#  31: (5, 5, 4)}

# %%
id2name
# Out:
# {0: 'Cortical subplate',
#  1: 'Hypothalamus',
#  2: 'Cerebral nuclei',
#  3: 'auditory area',
#  4: 'Hippocampal formation',
#  5: 'Thalamus',
#  6: 'Retrosplenial area',
#  7: 'Olfactory area',
#  8: 'Somatosensory area',
#  9: 'dump',
#  10: 'dump',
#  11: 'dump',
#  12: 'dump',
#  13: 'dump',
#  14: 'dump',
#  15: 'dump',
#  16: 'dump',
#  17: 'dump',
#  18: 'dump',
#  19: 'dump',
#  20: 'dump',
#  21: 'dump',
#  22: 'dump',
#  23: 'dump',
#  24: 'dump',
#  25: 'dump',
#  26: 'dump',
#  27: 'dump',
#  28: 'dump',
#  29: 'dump',
#  30: 'dump',
#  31: 'dump'}

# %% [markdown]
# ### Define functions for one hot encoding rgb labels, and decoding encoded predictions

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# # Creating custom Image data generators

# %% [markdown]
# ### Defining data generators

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)
test_frames_datagen = ImageDataGenerator(**data_gen_args)
test_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %% [markdown]
# ### Custom image data generators for creating batches of frames and masks

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 5):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
    DATA_PATH + 'train_frames/',
    batch_size = batch_size, seed = seed)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    DATA_PATH + 'train_masks/',
    batch_size = batch_size, seed = seed)

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(seed = 1, batch_size = 5):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
    DATA_PATH + 'val_frames/',
    batch_size = batch_size, seed = seed)


    val_mask_generator = val_masks_datagen.flow_from_directory(
    DATA_PATH + 'val_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)
        
def TestAugmentGenerator(seed = 1, batch_size = 10):
    '''Test Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    test_image_generator = test_frames_datagen.flow_from_directory(
    DATA_PATH + 'test_frames/',
    batch_size = batch_size, seed = seed)


    test_mask_generator = test_masks_datagen.flow_from_directory(
    DATA_PATH + 'test_masks/',
    batch_size = batch_size, seed = seed)


    while True:
        X1i = test_image_generator.next()
        X2i = test_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %% [markdown]
# # Defining U-Net model for semantic segmentation
# <b>U-Net Architecture</b>
#
# <div style="text-align: center;">
#
#         <img src="https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png" alt="U-Net" height="600" width="800">
# </div>
#
# [Picture Credits](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/)<br><br>

# %%
def get_small_unet(n_filters = 16, bn = True, dilation_rate = 1):
    '''Validation Image data generator
        Inputs: 
            n_filters - base convolution filters
            bn - flag to set batch normalization
            dilation_rate - convolution dilation rate
        Output: Unet keras Model
    '''
    #Define input batch shape
    shape=(256,256,3)
    inputs = Input(shape)
    print(inputs)
    
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(inputs)
    if bn:
        conv1 = BatchNormalization()(conv1)
        
    conv1 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv1)
    if bn:
        conv1 = BatchNormalization()(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv1)

    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool1)
    if bn:
        conv2 = BatchNormalization()(conv2)
        
    conv2 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv2)
    if bn:
        conv2 = BatchNormalization()(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv2)

    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool2)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    conv3 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv3)
    if bn:
        conv3 = BatchNormalization()(conv3)
        
    pool3 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv3)

    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool3)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    conv4 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv4)
    if bn:
        conv4 = BatchNormalization()(conv4)
        
    pool4 = MaxPooling2D(pool_size=(2, 2), data_format='channels_last')(conv4)

    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(pool4)
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    conv5 = Conv2D(n_filters * 16, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv5)
    if bn:
        conv5 = BatchNormalization()(conv5)
        
    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=3)
    
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    conv6 = Conv2D(n_filters * 8, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv6)
    if bn:
        conv6 = BatchNormalization()(conv6)
        
    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=3)
    
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    conv7 = Conv2D(n_filters * 4, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv7)
    if bn:
        conv7 = BatchNormalization()(conv7)
        
    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=3)
    
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up8)
    if bn:
        conv8 = BatchNormalization()(conv8)
        
    conv8 = Conv2D(n_filters * 2, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv8)
    if bn:
        conv8 = BatchNormalization()(conv8)
        
    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=3)
    
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(up9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv9 = Conv2D(n_filters * 1, (3, 3), activation='relu', padding = 'same', dilation_rate = dilation_rate)(conv9)
    if bn:
        conv9 = BatchNormalization()(conv9)
        
    conv10 = Conv2D(32, (1, 1), activation='softmax', padding = 'same', dilation_rate = dilation_rate)(conv9)

    model = Model(inputs=inputs, outputs=conv10)
        
    return model

# %% [markdown]
# ## Generating U-Net model

# %%
model = get_small_unet(n_filters = 32)
# Out:
# Tensor("input_1:0", shape=(?, 256, 256, 3), dtype=float32)

# %% [markdown]
# ## Defining dice co-efficients for model performance

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
def iou(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) - intersection + smooth)

# %%
smooth = 1.

# %% [markdown]
# ## Compiling model
# - Using categorical crossentropy loss since labels have been one hot encoded

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[tversky_loss,dice_coef,tf.keras.metrics.Recall(),tf.keras.metrics.Precision(),iou,'accuracy'])

# %%
# model.summary()

# %%
# model.load_weights("camvid_model_100_epochs_v1_aug.h5")

# %% [markdown]
# ## Define model callback settings

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='camvid_model_100_epochs_checkpoint_v1_aug.h5', monitor='accuracy', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_accuracy', patience=10, verbose=1)
callbacks = [tb, mc, es]

# %% [markdown]
# ## Train and save the U-Net model

# %%
batch_size = 5
steps_per_epoch = np.ceil(float(len(frames_list) - round(0.1*len(frames_list))) / float(batch_size))
steps_per_epoch
# Out:
# 274.0

# %%
validation_steps = (float((round(0.1*len(frames_list)))) / float(batch_size))
validation_steps
# Out:
# 30.4

# %%
num_epochs = 100

# %%
###### Train model
import pandas as pd

batch_size = 5
result = model.fit_generator(TrainAugmentGenerator(), steps_per_epoch=steps_per_epoch ,
                validation_data = ValAugmentGenerator(), 
                validation_steps = validation_steps, epochs=num_epochs, callbacks=callbacks)
model.save_weights("camvid_model_Unet_v1_aug.h5", overwrite=True)

# save result log
hist_df = pd.DataFrame(result.history)
hist_csv_file = 'SegNet_v1.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)
# Out:
# Epoch 1/100
# Found 1218 images belonging to 1 classes.
# Found 1218 images belonging to 1 classes.
# WARNING:tensorflow:From /home/mirap/anaconda3/envs/alpha/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 273/274 [============================>.] - ETA: 0s - loss: 0.4024 - tversky_loss: 31.3642 - dice_coef: 0.8274 - iou: 0.7199 - acc: 0.7342Found 294 images belonging to 1 classes.
# Found 294 images belonging to 1 classes.
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 231s 843ms/step - loss: 0.4015 - tversky_loss: 31.3638 - dice_coef: 0.8276 - iou: 0.7201 - acc: 0.7345 - val_loss: 1.4180 - val_tversky_loss: 31.5823 - val_dice_coef: 0.5185 - val_iou: 0.3503 - val_acc: 0.6243
# Epoch 2/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.1208 - tversky_loss: 31.2277 - dice_coef: 0.8799 - iou: 0.7864 - acc: 0.8365WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.1207 - tversky_loss: 31.2277 - dice_coef: 0.8799 - iou: 0.7863 - acc: 0.8365 - val_loss: 0.3002 - val_tversky_loss: 31.2777 - val_dice_coef: 0.7732 - val_iou: 0.6314 - val_acc: 0.8384
# Epoch 3/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.1085 - tversky_loss: 31.2160 - dice_coef: 0.8764 - iou: 0.7809 - acc: 0.8605WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 216s 787ms/step - loss: 0.1084 - tversky_loss: 31.2157 - dice_coef: 0.8766 - iou: 0.7813 - acc: 0.8607 - val_loss: 0.2564 - val_tversky_loss: 31.2460 - val_dice_coef: 0.8440 - val_iou: 0.7305 - val_acc: 0.8092
# Epoch 4/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0649 - tversky_loss: 31.1921 - dice_coef: 0.8878 - iou: 0.7993 - acc: 0.8649WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0649 - tversky_loss: 31.1920 - dice_coef: 0.8879 - iou: 0.7994 - acc: 0.8650 - val_loss: 0.2778 - val_tversky_loss: 31.2205 - val_dice_coef: 0.8534 - val_iou: 0.7449 - val_acc: 0.8277
# Epoch 5/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0595 - tversky_loss: 31.1864 - dice_coef: 0.8784 - iou: 0.7843 - acc: 0.8970WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 794ms/step - loss: 0.0595 - tversky_loss: 31.1862 - dice_coef: 0.8785 - iou: 0.7845 - acc: 0.8971 - val_loss: 0.2780 - val_tversky_loss: 31.2209 - val_dice_coef: 0.8427 - val_iou: 0.7286 - val_acc: 0.8481
# Epoch 6/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0462 - tversky_loss: 31.1758 - dice_coef: 0.8854 - iou: 0.7951 - acc: 0.8965WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 794ms/step - loss: 0.0462 - tversky_loss: 31.1758 - dice_coef: 0.8854 - iou: 0.7951 - acc: 0.8965 - val_loss: 0.3080 - val_tversky_loss: 31.2218 - val_dice_coef: 0.8348 - val_iou: 0.7170 - val_acc: 0.8576
# Epoch 7/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0422 - tversky_loss: 31.1784 - dice_coef: 0.8883 - iou: 0.7998 - acc: 0.8819WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0422 - tversky_loss: 31.1783 - dice_coef: 0.8884 - iou: 0.8000 - acc: 0.8820 - val_loss: 0.2560 - val_tversky_loss: 31.2152 - val_dice_coef: 0.8540 - val_iou: 0.7459 - val_acc: 0.8346
# Epoch 8/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0359 - tversky_loss: 31.1703 - dice_coef: 0.8928 - iou: 0.8073 - acc: 0.8886WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0359 - tversky_loss: 31.1703 - dice_coef: 0.8928 - iou: 0.8073 - acc: 0.8885 - val_loss: 0.3109 - val_tversky_loss: 31.2345 - val_dice_coef: 0.8308 - val_iou: 0.7108 - val_acc: 0.8355
# Epoch 9/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0331 - tversky_loss: 31.1701 - dice_coef: 0.8845 - iou: 0.7938 - acc: 0.9030WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0331 - tversky_loss: 31.1698 - dice_coef: 0.8848 - iou: 0.7943 - acc: 0.9032 - val_loss: 0.3095 - val_tversky_loss: 31.2082 - val_dice_coef: 0.8429 - val_iou: 0.7292 - val_acc: 0.8653
# Epoch 10/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0305 - tversky_loss: 31.1668 - dice_coef: 0.8860 - iou: 0.7962 - acc: 0.9041WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 795ms/step - loss: 0.0305 - tversky_loss: 31.1669 - dice_coef: 0.8859 - iou: 0.7961 - acc: 0.9041 - val_loss: 0.3218 - val_tversky_loss: 31.2181 - val_dice_coef: 0.8439 - val_iou: 0.7305 - val_acc: 0.8378
# Epoch 11/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0285 - tversky_loss: 31.1673 - dice_coef: 0.8903 - iou: 0.8032 - acc: 0.8932WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0285 - tversky_loss: 31.1675 - dice_coef: 0.8902 - iou: 0.8030 - acc: 0.8931 - val_loss: 0.3456 - val_tversky_loss: 31.2106 - val_dice_coef: 0.8471 - val_iou: 0.7353 - val_acc: 0.8456
# Epoch 12/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0269 - tversky_loss: 31.1665 - dice_coef: 0.8923 - iou: 0.8063 - acc: 0.8897WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 804ms/step - loss: 0.0269 - tversky_loss: 31.1666 - dice_coef: 0.8922 - iou: 0.8062 - acc: 0.8897 - val_loss: 0.3325 - val_tversky_loss: 31.2171 - val_dice_coef: 0.8415 - val_iou: 0.7269 - val_acc: 0.8430
# Epoch 13/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0268 - tversky_loss: 31.1631 - dice_coef: 0.8890 - iou: 0.8012 - acc: 0.9035WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0268 - tversky_loss: 31.1631 - dice_coef: 0.8891 - iou: 0.8012 - acc: 0.9035 - val_loss: 0.3402 - val_tversky_loss: 31.2171 - val_dice_coef: 0.8419 - val_iou: 0.7275 - val_acc: 0.8347
# Epoch 14/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0459 - tversky_loss: 31.1771 - dice_coef: 0.8773 - iou: 0.7823 - acc: 0.9019WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 803ms/step - loss: 0.0458 - tversky_loss: 31.1769 - dice_coef: 0.8775 - iou: 0.7827 - acc: 0.9021 - val_loss: 0.3477 - val_tversky_loss: 31.2199 - val_dice_coef: 0.8356 - val_iou: 0.7183 - val_acc: 0.8509
# Epoch 15/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0256 - tversky_loss: 31.1636 - dice_coef: 0.8855 - iou: 0.7954 - acc: 0.9093WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 793ms/step - loss: 0.0255 - tversky_loss: 31.1638 - dice_coef: 0.8855 - iou: 0.7952 - acc: 0.9091 - val_loss: 0.3098 - val_tversky_loss: 31.2062 - val_dice_coef: 0.8487 - val_iou: 0.7377 - val_acc: 0.8532
# Epoch 16/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0227 - tversky_loss: 31.1630 - dice_coef: 0.8875 - iou: 0.7986 - acc: 0.9051WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.0227 - tversky_loss: 31.1631 - dice_coef: 0.8874 - iou: 0.7984 - acc: 0.9050 - val_loss: 0.3880 - val_tversky_loss: 31.2160 - val_dice_coef: 0.8320 - val_iou: 0.7128 - val_acc: 0.8588
# Epoch 17/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0211 - tversky_loss: 31.1607 - dice_coef: 0.8914 - iou: 0.8049 - acc: 0.9006WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 801ms/step - loss: 0.0211 - tversky_loss: 31.1607 - dice_coef: 0.8914 - iou: 0.8048 - acc: 0.9005 - val_loss: 0.3882 - val_tversky_loss: 31.2172 - val_dice_coef: 0.8335 - val_iou: 0.7150 - val_acc: 0.8508
# Epoch 18/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0209 - tversky_loss: 31.1602 - dice_coef: 0.8855 - iou: 0.7956 - acc: 0.9121WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 793ms/step - loss: 0.0209 - tversky_loss: 31.1603 - dice_coef: 0.8854 - iou: 0.7954 - acc: 0.9121 - val_loss: 0.3852 - val_tversky_loss: 31.2085 - val_dice_coef: 0.8267 - val_iou: 0.7056 - val_acc: 0.8841
# Epoch 19/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0197 - tversky_loss: 31.1609 - dice_coef: 0.8800 - iou: 0.7866 - acc: 0.9213WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 794ms/step - loss: 0.0197 - tversky_loss: 31.1607 - dice_coef: 0.8802 - iou: 0.7869 - acc: 0.9214 - val_loss: 0.3919 - val_tversky_loss: 31.2130 - val_dice_coef: 0.8278 - val_iou: 0.7069 - val_acc: 0.8721
# Epoch 20/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0190 - tversky_loss: 31.1594 - dice_coef: 0.8839 - iou: 0.7929 - acc: 0.9160WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 793ms/step - loss: 0.0189 - tversky_loss: 31.1595 - dice_coef: 0.8839 - iou: 0.7928 - acc: 0.9160 - val_loss: 0.4069 - val_tversky_loss: 31.2125 - val_dice_coef: 0.8297 - val_iou: 0.7096 - val_acc: 0.8701
# Epoch 21/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0185 - tversky_loss: 31.1598 - dice_coef: 0.8824 - iou: 0.7904 - acc: 0.9178WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0185 - tversky_loss: 31.1597 - dice_coef: 0.8824 - iou: 0.7904 - acc: 0.9178 - val_loss: 0.4161 - val_tversky_loss: 31.2166 - val_dice_coef: 0.8264 - val_iou: 0.7046 - val_acc: 0.8655
# Epoch 22/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0179 - tversky_loss: 31.1604 - dice_coef: 0.8830 - iou: 0.7915 - acc: 0.9152WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 804ms/step - loss: 0.0179 - tversky_loss: 31.1603 - dice_coef: 0.8830 - iou: 0.7915 - acc: 0.9153 - val_loss: 0.4117 - val_tversky_loss: 31.2175 - val_dice_coef: 0.8234 - val_iou: 0.7003 - val_acc: 0.8697
# Epoch 23/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0177 - tversky_loss: 31.1606 - dice_coef: 0.8818 - iou: 0.7896 - acc: 0.9163WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 221s 807ms/step - loss: 0.0177 - tversky_loss: 31.1605 - dice_coef: 0.8818 - iou: 0.7896 - acc: 0.9163 - val_loss: 0.4330 - val_tversky_loss: 31.2114 - val_dice_coef: 0.8345 - val_iou: 0.7168 - val_acc: 0.8528
# Epoch 24/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0171 - tversky_loss: 31.1565 - dice_coef: 0.8842 - iou: 0.7935 - acc: 0.9192WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 801ms/step - loss: 0.0171 - tversky_loss: 31.1564 - dice_coef: 0.8843 - iou: 0.7936 - acc: 0.9193 - val_loss: 0.4420 - val_tversky_loss: 31.2126 - val_dice_coef: 0.8255 - val_iou: 0.7035 - val_acc: 0.8712
# Epoch 25/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0165 - tversky_loss: 31.1579 - dice_coef: 0.8844 - iou: 0.7936 - acc: 0.9146WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0165 - tversky_loss: 31.1580 - dice_coef: 0.8843 - iou: 0.7935 - acc: 0.9145 - val_loss: 0.4339 - val_tversky_loss: 31.2147 - val_dice_coef: 0.8250 - val_iou: 0.7028 - val_acc: 0.8703
# Epoch 26/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0160 - tversky_loss: 31.1580 - dice_coef: 0.8843 - iou: 0.7937 - acc: 0.9142WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 221s 807ms/step - loss: 0.0160 - tversky_loss: 31.1582 - dice_coef: 0.8842 - iou: 0.7934 - acc: 0.9141 - val_loss: 0.4573 - val_tversky_loss: 31.2073 - val_dice_coef: 0.8295 - val_iou: 0.7095 - val_acc: 0.8721
# Epoch 27/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0156 - tversky_loss: 31.1575 - dice_coef: 0.8860 - iou: 0.7961 - acc: 0.9104WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0156 - tversky_loss: 31.1574 - dice_coef: 0.8860 - iou: 0.7961 - acc: 0.9105 - val_loss: 0.4373 - val_tversky_loss: 31.2113 - val_dice_coef: 0.8293 - val_iou: 0.7091 - val_acc: 0.8656
# Epoch 28/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0158 - tversky_loss: 31.1575 - dice_coef: 0.8862 - iou: 0.7966 - acc: 0.9102WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0158 - tversky_loss: 31.1577 - dice_coef: 0.8860 - iou: 0.7964 - acc: 0.9100 - val_loss: 0.4314 - val_tversky_loss: 31.2208 - val_dice_coef: 0.8183 - val_iou: 0.6930 - val_acc: 0.8641
# Epoch 29/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0432 - tversky_loss: 31.1733 - dice_coef: 0.8486 - iou: 0.7385 - acc: 0.9770WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 221s 805ms/step - loss: 0.0431 - tversky_loss: 31.1733 - dice_coef: 0.8486 - iou: 0.7384 - acc: 0.9770 - val_loss: 0.3259 - val_tversky_loss: 31.2127 - val_dice_coef: 0.8052 - val_iou: 0.6750 - val_acc: 0.9362
# Epoch 30/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0185 - tversky_loss: 31.1600 - dice_coef: 0.8625 - iou: 0.7592 - acc: 0.9746WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0185 - tversky_loss: 31.1601 - dice_coef: 0.8624 - iou: 0.7591 - acc: 0.9745 - val_loss: 0.3635 - val_tversky_loss: 31.2080 - val_dice_coef: 0.8188 - val_iou: 0.6943 - val_acc: 0.9222
# Epoch 31/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0155 - tversky_loss: 31.1568 - dice_coef: 0.8711 - iou: 0.7728 - acc: 0.9506WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0155 - tversky_loss: 31.1570 - dice_coef: 0.8710 - iou: 0.7726 - acc: 0.9505 - val_loss: 0.4106 - val_tversky_loss: 31.2049 - val_dice_coef: 0.8214 - val_iou: 0.6979 - val_acc: 0.9072
# Epoch 32/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0142 - tversky_loss: 31.1565 - dice_coef: 0.8724 - iou: 0.7749 - acc: 0.9345WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.0142 - tversky_loss: 31.1566 - dice_coef: 0.8724 - iou: 0.7748 - acc: 0.9345 - val_loss: 0.4724 - val_tversky_loss: 31.2139 - val_dice_coef: 0.8110 - val_iou: 0.6832 - val_acc: 0.9072
# Epoch 33/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0135 - tversky_loss: 31.1569 - dice_coef: 0.8722 - iou: 0.7744 - acc: 0.9379WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0135 - tversky_loss: 31.1570 - dice_coef: 0.8722 - iou: 0.7743 - acc: 0.9379 - val_loss: 0.4217 - val_tversky_loss: 31.2097 - val_dice_coef: 0.8195 - val_iou: 0.6954 - val_acc: 0.9047
# Epoch 34/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0130 - tversky_loss: 31.1556 - dice_coef: 0.8744 - iou: 0.7781 - acc: 0.9359WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0130 - tversky_loss: 31.1556 - dice_coef: 0.8744 - iou: 0.7780 - acc: 0.9359 - val_loss: 0.4815 - val_tversky_loss: 31.2169 - val_dice_coef: 0.8125 - val_iou: 0.6852 - val_acc: 0.8866
# Epoch 35/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0128 - tversky_loss: 31.1559 - dice_coef: 0.8744 - iou: 0.7778 - acc: 0.9383WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0128 - tversky_loss: 31.1561 - dice_coef: 0.8742 - iou: 0.7776 - acc: 0.9382 - val_loss: 0.4692 - val_tversky_loss: 31.2104 - val_dice_coef: 0.8213 - val_iou: 0.6974 - val_acc: 0.8869
# Epoch 36/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0123 - tversky_loss: 31.1546 - dice_coef: 0.8773 - iou: 0.7824 - acc: 0.9319WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 791ms/step - loss: 0.0123 - tversky_loss: 31.1546 - dice_coef: 0.8773 - iou: 0.7824 - acc: 0.9319 - val_loss: 0.4732 - val_tversky_loss: 31.2082 - val_dice_coef: 0.8265 - val_iou: 0.7049 - val_acc: 0.8672
# Epoch 37/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0124 - tversky_loss: 31.1563 - dice_coef: 0.8754 - iou: 0.7796 - acc: 0.9277WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 794ms/step - loss: 0.0124 - tversky_loss: 31.1560 - dice_coef: 0.8756 - iou: 0.7799 - acc: 0.9280 - val_loss: 0.4959 - val_tversky_loss: 31.2134 - val_dice_coef: 0.8071 - val_iou: 0.6777 - val_acc: 0.9096
# Epoch 38/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0122 - tversky_loss: 31.1548 - dice_coef: 0.8743 - iou: 0.7778 - acc: 0.9346WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 216s 789ms/step - loss: 0.0122 - tversky_loss: 31.1551 - dice_coef: 0.8741 - iou: 0.7775 - acc: 0.9345 - val_loss: 0.4631 - val_tversky_loss: 31.2043 - val_dice_coef: 0.8190 - val_iou: 0.6945 - val_acc: 0.9084
# Epoch 39/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0117 - tversky_loss: 31.1553 - dice_coef: 0.8748 - iou: 0.7785 - acc: 0.9296WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0118 - tversky_loss: 31.1555 - dice_coef: 0.8747 - iou: 0.7783 - acc: 0.9296 - val_loss: 0.5140 - val_tversky_loss: 31.2179 - val_dice_coef: 0.8099 - val_iou: 0.6814 - val_acc: 0.8877
# Epoch 40/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0118 - tversky_loss: 31.1548 - dice_coef: 0.8751 - iou: 0.7792 - acc: 0.9267WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 794ms/step - loss: 0.0118 - tversky_loss: 31.1547 - dice_coef: 0.8753 - iou: 0.7794 - acc: 0.9267 - val_loss: 0.4798 - val_tversky_loss: 31.2139 - val_dice_coef: 0.8155 - val_iou: 0.6892 - val_acc: 0.8784
# Epoch 41/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0117 - tversky_loss: 31.1544 - dice_coef: 0.8767 - iou: 0.7815 - acc: 0.9290WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0117 - tversky_loss: 31.1545 - dice_coef: 0.8767 - iou: 0.7814 - acc: 0.9290 - val_loss: 0.4577 - val_tversky_loss: 31.2124 - val_dice_coef: 0.8161 - val_iou: 0.6899 - val_acc: 0.8914
# Epoch 42/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0114 - tversky_loss: 31.1563 - dice_coef: 0.8748 - iou: 0.7785 - acc: 0.9225WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 797ms/step - loss: 0.0114 - tversky_loss: 31.1564 - dice_coef: 0.8748 - iou: 0.7784 - acc: 0.9225 - val_loss: 0.5118 - val_tversky_loss: 31.2121 - val_dice_coef: 0.8166 - val_iou: 0.6907 - val_acc: 0.8758
# Epoch 43/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0113 - tversky_loss: 31.1539 - dice_coef: 0.8763 - iou: 0.7809 - acc: 0.9266WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 793ms/step - loss: 0.0113 - tversky_loss: 31.1538 - dice_coef: 0.8764 - iou: 0.7811 - acc: 0.9265 - val_loss: 0.5189 - val_tversky_loss: 31.2167 - val_dice_coef: 0.8188 - val_iou: 0.6939 - val_acc: 0.8514
# Epoch 44/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0112 - tversky_loss: 31.1543 - dice_coef: 0.8770 - iou: 0.7823 - acc: 0.9222WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0112 - tversky_loss: 31.1543 - dice_coef: 0.8771 - iou: 0.7823 - acc: 0.9222 - val_loss: 0.5233 - val_tversky_loss: 31.2068 - val_dice_coef: 0.8220 - val_iou: 0.6987 - val_acc: 0.8729
# Epoch 45/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0110 - tversky_loss: 31.1534 - dice_coef: 0.8760 - iou: 0.7805 - acc: 0.9240WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0110 - tversky_loss: 31.1534 - dice_coef: 0.8761 - iou: 0.7805 - acc: 0.9240 - val_loss: 0.5378 - val_tversky_loss: 31.2104 - val_dice_coef: 0.8208 - val_iou: 0.6971 - val_acc: 0.8662
# Epoch 46/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0109 - tversky_loss: 31.1553 - dice_coef: 0.8748 - iou: 0.7785 - acc: 0.9246WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 791ms/step - loss: 0.0109 - tversky_loss: 31.1554 - dice_coef: 0.8747 - iou: 0.7784 - acc: 0.9244 - val_loss: 0.4645 - val_tversky_loss: 31.2120 - val_dice_coef: 0.8195 - val_iou: 0.6951 - val_acc: 0.8820
# Epoch 47/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0106 - tversky_loss: 31.1527 - dice_coef: 0.8785 - iou: 0.7843 - acc: 0.9236WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 216s 790ms/step - loss: 0.0106 - tversky_loss: 31.1527 - dice_coef: 0.8784 - iou: 0.7842 - acc: 0.9235 - val_loss: 0.5224 - val_tversky_loss: 31.2097 - val_dice_coef: 0.8186 - val_iou: 0.6937 - val_acc: 0.8752
# Epoch 48/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0103 - tversky_loss: 31.1560 - dice_coef: 0.8750 - iou: 0.7790 - acc: 0.9208WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0103 - tversky_loss: 31.1557 - dice_coef: 0.8752 - iou: 0.7793 - acc: 0.9210 - val_loss: 0.4895 - val_tversky_loss: 31.2139 - val_dice_coef: 0.8178 - val_iou: 0.6925 - val_acc: 0.8566
# Epoch 49/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0101 - tversky_loss: 31.1541 - dice_coef: 0.8760 - iou: 0.7805 - acc: 0.9125WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 791ms/step - loss: 0.0101 - tversky_loss: 31.1540 - dice_coef: 0.8761 - iou: 0.7806 - acc: 0.9126 - val_loss: 0.5426 - val_tversky_loss: 31.2070 - val_dice_coef: 0.8196 - val_iou: 0.6947 - val_acc: 0.8672
# Epoch 50/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0099 - tversky_loss: 31.1543 - dice_coef: 0.8743 - iou: 0.7778 - acc: 0.9184WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0099 - tversky_loss: 31.1543 - dice_coef: 0.8743 - iou: 0.7778 - acc: 0.9183 - val_loss: 0.5118 - val_tversky_loss: 31.2178 - val_dice_coef: 0.8126 - val_iou: 0.6851 - val_acc: 0.8597
# Epoch 51/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0097 - tversky_loss: 31.1522 - dice_coef: 0.8753 - iou: 0.7794 - acc: 0.9199WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 216s 790ms/step - loss: 0.0097 - tversky_loss: 31.1524 - dice_coef: 0.8752 - iou: 0.7792 - acc: 0.9197 - val_loss: 0.5369 - val_tversky_loss: 31.2191 - val_dice_coef: 0.8105 - val_iou: 0.6825 - val_acc: 0.8582
# Epoch 52/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0095 - tversky_loss: 31.1535 - dice_coef: 0.8753 - iou: 0.7796 - acc: 0.9131WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0095 - tversky_loss: 31.1535 - dice_coef: 0.8753 - iou: 0.7797 - acc: 0.9132 - val_loss: 0.5092 - val_tversky_loss: 31.2035 - val_dice_coef: 0.8251 - val_iou: 0.7029 - val_acc: 0.8611
# Epoch 53/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0095 - tversky_loss: 31.1546 - dice_coef: 0.8749 - iou: 0.7789 - acc: 0.9149WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0095 - tversky_loss: 31.1547 - dice_coef: 0.8748 - iou: 0.7787 - acc: 0.9147 - val_loss: 0.5568 - val_tversky_loss: 31.2121 - val_dice_coef: 0.8142 - val_iou: 0.6877 - val_acc: 0.8679
# Epoch 54/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0092 - tversky_loss: 31.1538 - dice_coef: 0.8735 - iou: 0.7766 - acc: 0.9240WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 797ms/step - loss: 0.0092 - tversky_loss: 31.1538 - dice_coef: 0.8735 - iou: 0.7766 - acc: 0.9240 - val_loss: 0.5315 - val_tversky_loss: 31.2123 - val_dice_coef: 0.8134 - val_iou: 0.6864 - val_acc: 0.8721
# Epoch 55/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0091 - tversky_loss: 31.1523 - dice_coef: 0.8739 - iou: 0.7772 - acc: 0.9243WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 221s 805ms/step - loss: 0.0091 - tversky_loss: 31.1523 - dice_coef: 0.8738 - iou: 0.7770 - acc: 0.9243 - val_loss: 0.5620 - val_tversky_loss: 31.2141 - val_dice_coef: 0.8103 - val_iou: 0.6820 - val_acc: 0.8855
# Epoch 56/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0090 - tversky_loss: 31.1530 - dice_coef: 0.8741 - iou: 0.7776 - acc: 0.9243WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0090 - tversky_loss: 31.1531 - dice_coef: 0.8741 - iou: 0.7776 - acc: 0.9242 - val_loss: 0.5544 - val_tversky_loss: 31.2110 - val_dice_coef: 0.8150 - val_iou: 0.6882 - val_acc: 0.8742
# Epoch 57/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0088 - tversky_loss: 31.1532 - dice_coef: 0.8749 - iou: 0.7786 - acc: 0.9151WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0088 - tversky_loss: 31.1531 - dice_coef: 0.8749 - iou: 0.7787 - acc: 0.9152 - val_loss: 0.5705 - val_tversky_loss: 31.2105 - val_dice_coef: 0.8127 - val_iou: 0.6854 - val_acc: 0.8732
# Epoch 58/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0085 - tversky_loss: 31.1527 - dice_coef: 0.8736 - iou: 0.7767 - acc: 0.9194WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0085 - tversky_loss: 31.1526 - dice_coef: 0.8737 - iou: 0.7768 - acc: 0.9195 - val_loss: 0.5613 - val_tversky_loss: 31.2195 - val_dice_coef: 0.8069 - val_iou: 0.6767 - val_acc: 0.8658
# Epoch 59/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0084 - tversky_loss: 31.1532 - dice_coef: 0.8725 - iou: 0.7750 - acc: 0.9162WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0084 - tversky_loss: 31.1534 - dice_coef: 0.8723 - iou: 0.7747 - acc: 0.9161 - val_loss: 0.5204 - val_tversky_loss: 31.2072 - val_dice_coef: 0.8124 - val_iou: 0.6854 - val_acc: 0.9020
# Epoch 60/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0082 - tversky_loss: 31.1516 - dice_coef: 0.8728 - iou: 0.7755 - acc: 0.9193WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0082 - tversky_loss: 31.1515 - dice_coef: 0.8729 - iou: 0.7756 - acc: 0.9193 - val_loss: 0.5700 - val_tversky_loss: 31.2132 - val_dice_coef: 0.8122 - val_iou: 0.6847 - val_acc: 0.8597
# Epoch 61/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0081 - tversky_loss: 31.1520 - dice_coef: 0.8719 - iou: 0.7740 - acc: 0.9220WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0081 - tversky_loss: 31.1519 - dice_coef: 0.8720 - iou: 0.7741 - acc: 0.9221 - val_loss: 0.5805 - val_tversky_loss: 31.2091 - val_dice_coef: 0.8141 - val_iou: 0.6874 - val_acc: 0.8759
# Epoch 62/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0081 - tversky_loss: 31.1537 - dice_coef: 0.8705 - iou: 0.7721 - acc: 0.9195WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0081 - tversky_loss: 31.1537 - dice_coef: 0.8705 - iou: 0.7720 - acc: 0.9195 - val_loss: 0.6094 - val_tversky_loss: 31.2168 - val_dice_coef: 0.8059 - val_iou: 0.6756 - val_acc: 0.8692
# Epoch 63/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0079 - tversky_loss: 31.1540 - dice_coef: 0.8694 - iou: 0.7703 - acc: 0.9194WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0079 - tversky_loss: 31.1541 - dice_coef: 0.8693 - iou: 0.7700 - acc: 0.9193 - val_loss: 0.5358 - val_tversky_loss: 31.2036 - val_dice_coef: 0.8203 - val_iou: 0.6961 - val_acc: 0.8697
# Epoch 64/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0077 - tversky_loss: 31.1502 - dice_coef: 0.8741 - iou: 0.7775 - acc: 0.9197WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0077 - tversky_loss: 31.1503 - dice_coef: 0.8740 - iou: 0.7773 - acc: 0.9196 - val_loss: 0.5816 - val_tversky_loss: 31.2141 - val_dice_coef: 0.8113 - val_iou: 0.6834 - val_acc: 0.8575
# Epoch 65/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0075 - tversky_loss: 31.1519 - dice_coef: 0.8716 - iou: 0.7734 - acc: 0.9205WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0075 - tversky_loss: 31.1522 - dice_coef: 0.8713 - iou: 0.7730 - acc: 0.9202 - val_loss: 0.6079 - val_tversky_loss: 31.2183 - val_dice_coef: 0.8060 - val_iou: 0.6758 - val_acc: 0.8525
# Epoch 66/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0076 - tversky_loss: 31.1539 - dice_coef: 0.8697 - iou: 0.7706 - acc: 0.9211WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.0076 - tversky_loss: 31.1540 - dice_coef: 0.8696 - iou: 0.7705 - acc: 0.9210 - val_loss: 0.5535 - val_tversky_loss: 31.2043 - val_dice_coef: 0.8170 - val_iou: 0.6912 - val_acc: 0.8803
# Epoch 67/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0075 - tversky_loss: 31.1491 - dice_coef: 0.8734 - iou: 0.7767 - acc: 0.9250WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0075 - tversky_loss: 31.1490 - dice_coef: 0.8735 - iou: 0.7769 - acc: 0.9251 - val_loss: 0.6024 - val_tversky_loss: 31.2162 - val_dice_coef: 0.8063 - val_iou: 0.6766 - val_acc: 0.8718
# Epoch 68/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0072 - tversky_loss: 31.1540 - dice_coef: 0.8687 - iou: 0.7690 - acc: 0.9209WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0072 - tversky_loss: 31.1539 - dice_coef: 0.8688 - iou: 0.7691 - acc: 0.9210 - val_loss: 0.6116 - val_tversky_loss: 31.2078 - val_dice_coef: 0.8140 - val_iou: 0.6872 - val_acc: 0.8687
# Epoch 69/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0072 - tversky_loss: 31.1522 - dice_coef: 0.8696 - iou: 0.7706 - acc: 0.9301WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# ...
# Epoch 78/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0062 - tversky_loss: 31.1492 - dice_coef: 0.8684 - iou: 0.7687 - acc: 0.9200WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0062 - tversky_loss: 31.1492 - dice_coef: 0.8684 - iou: 0.7688 - acc: 0.9201 - val_loss: 0.6143 - val_tversky_loss: 31.2124 - val_dice_coef: 0.8061 - val_iou: 0.6762 - val_acc: 0.8596
# Epoch 79/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0062 - tversky_loss: 31.1523 - dice_coef: 0.8655 - iou: 0.7643 - acc: 0.9146WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0062 - tversky_loss: 31.1522 - dice_coef: 0.8656 - iou: 0.7644 - acc: 0.9147 - val_loss: 0.6184 - val_tversky_loss: 31.2112 - val_dice_coef: 0.8068 - val_iou: 0.6777 - val_acc: 0.8522
# Epoch 80/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0061 - tversky_loss: 31.1522 - dice_coef: 0.8647 - iou: 0.7628 - acc: 0.9178WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 802ms/step - loss: 0.0061 - tversky_loss: 31.1521 - dice_coef: 0.8648 - iou: 0.7630 - acc: 0.9178 - val_loss: 0.6481 - val_tversky_loss: 31.2115 - val_dice_coef: 0.8045 - val_iou: 0.6743 - val_acc: 0.8633
# Epoch 81/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0059 - tversky_loss: 31.1495 - dice_coef: 0.8674 - iou: 0.7671 - acc: 0.9201WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.0059 - tversky_loss: 31.1496 - dice_coef: 0.8673 - iou: 0.7670 - acc: 0.9201 - val_loss: 0.6191 - val_tversky_loss: 31.2085 - val_dice_coef: 0.8072 - val_iou: 0.6776 - val_acc: 0.8749
# Epoch 82/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0059 - tversky_loss: 31.1516 - dice_coef: 0.8645 - iou: 0.7627 - acc: 0.9189WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0059 - tversky_loss: 31.1517 - dice_coef: 0.8645 - iou: 0.7626 - acc: 0.9188 - val_loss: 0.6370 - val_tversky_loss: 31.2146 - val_dice_coef: 0.8023 - val_iou: 0.6711 - val_acc: 0.8598
# Epoch 83/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0057 - tversky_loss: 31.1509 - dice_coef: 0.8647 - iou: 0.7631 - acc: 0.9201WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0057 - tversky_loss: 31.1509 - dice_coef: 0.8647 - iou: 0.7631 - acc: 0.9201 - val_loss: 0.6283 - val_tversky_loss: 31.2077 - val_dice_coef: 0.8076 - val_iou: 0.6779 - val_acc: 0.8721
# Epoch 84/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0059 - tversky_loss: 31.1504 - dice_coef: 0.8655 - iou: 0.7644 - acc: 0.9192WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0059 - tversky_loss: 31.1507 - dice_coef: 0.8653 - iou: 0.7641 - acc: 0.9191 - val_loss: 0.6331 - val_tversky_loss: 31.2095 - val_dice_coef: 0.8057 - val_iou: 0.6756 - val_acc: 0.8702
# Epoch 85/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0057 - tversky_loss: 31.1514 - dice_coef: 0.8649 - iou: 0.7632 - acc: 0.9196WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 794ms/step - loss: 0.0057 - tversky_loss: 31.1514 - dice_coef: 0.8648 - iou: 0.7632 - acc: 0.9196 - val_loss: 0.6170 - val_tversky_loss: 31.2121 - val_dice_coef: 0.8032 - val_iou: 0.6720 - val_acc: 0.8796
# Epoch 86/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0055 - tversky_loss: 31.1509 - dice_coef: 0.8643 - iou: 0.7622 - acc: 0.9229WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0055 - tversky_loss: 31.1509 - dice_coef: 0.8643 - iou: 0.7622 - acc: 0.9229 - val_loss: 0.6325 - val_tversky_loss: 31.2108 - val_dice_coef: 0.8053 - val_iou: 0.6750 - val_acc: 0.8729
# Epoch 87/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0055 - tversky_loss: 31.1510 - dice_coef: 0.8642 - iou: 0.7624 - acc: 0.9194WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 797ms/step - loss: 0.0055 - tversky_loss: 31.1510 - dice_coef: 0.8642 - iou: 0.7624 - acc: 0.9195 - val_loss: 0.6438 - val_tversky_loss: 31.2046 - val_dice_coef: 0.8101 - val_iou: 0.6815 - val_acc: 0.8705
# Epoch 88/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0054 - tversky_loss: 31.1516 - dice_coef: 0.8631 - iou: 0.7606 - acc: 0.9177WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 799ms/step - loss: 0.0054 - tversky_loss: 31.1518 - dice_coef: 0.8630 - iou: 0.7604 - acc: 0.9176 - val_loss: 0.6139 - val_tversky_loss: 31.2104 - val_dice_coef: 0.8044 - val_iou: 0.6741 - val_acc: 0.8720
# Epoch 89/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0053 - tversky_loss: 31.1489 - dice_coef: 0.8655 - iou: 0.7643 - acc: 0.9220WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0053 - tversky_loss: 31.1491 - dice_coef: 0.8654 - iou: 0.7641 - acc: 0.9219 - val_loss: 0.6167 - val_tversky_loss: 31.2100 - val_dice_coef: 0.8051 - val_iou: 0.6750 - val_acc: 0.8570
# Epoch 90/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0053 - tversky_loss: 31.1505 - dice_coef: 0.8638 - iou: 0.7617 - acc: 0.9176WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0053 - tversky_loss: 31.1507 - dice_coef: 0.8636 - iou: 0.7614 - acc: 0.9175 - val_loss: 0.6906 - val_tversky_loss: 31.2076 - val_dice_coef: 0.8052 - val_iou: 0.6750 - val_acc: 0.8759
# Epoch 91/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0052 - tversky_loss: 31.1492 - dice_coef: 0.8643 - iou: 0.7626 - acc: 0.9168WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 800ms/step - loss: 0.0052 - tversky_loss: 31.1492 - dice_coef: 0.8643 - iou: 0.7626 - acc: 0.9169 - val_loss: 0.6159 - val_tversky_loss: 31.2126 - val_dice_coef: 0.8001 - val_iou: 0.6678 - val_acc: 0.8640
# Epoch 92/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0054 - tversky_loss: 31.1522 - dice_coef: 0.8608 - iou: 0.7569 - acc: 0.9136WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 220s 804ms/step - loss: 0.0054 - tversky_loss: 31.1521 - dice_coef: 0.8609 - iou: 0.7571 - acc: 0.9137 - val_loss: 0.6391 - val_tversky_loss: 31.2166 - val_dice_coef: 0.7930 - val_iou: 0.6581 - val_acc: 0.8937
# Epoch 93/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0075 - tversky_loss: 31.1512 - dice_coef: 0.8618 - iou: 0.7587 - acc: 0.9263WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 219s 798ms/step - loss: 0.0075 - tversky_loss: 31.1513 - dice_coef: 0.8617 - iou: 0.7585 - acc: 0.9263 - val_loss: 0.5973 - val_tversky_loss: 31.2198 - val_dice_coef: 0.7934 - val_iou: 0.6586 - val_acc: 0.8760
# Epoch 94/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0049 - tversky_loss: 31.1491 - dice_coef: 0.8627 - iou: 0.7599 - acc: 0.9253WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 795ms/step - loss: 0.0049 - tversky_loss: 31.1490 - dice_coef: 0.8628 - iou: 0.7601 - acc: 0.9253 - val_loss: 0.6602 - val_tversky_loss: 31.2014 - val_dice_coef: 0.8105 - val_iou: 0.6822 - val_acc: 0.8722
# Epoch 95/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0048 - tversky_loss: 31.1529 - dice_coef: 0.8591 - iou: 0.7543 - acc: 0.9170WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 793ms/step - loss: 0.0048 - tversky_loss: 31.1530 - dice_coef: 0.8591 - iou: 0.7543 - acc: 0.9169 - val_loss: 0.6760 - val_tversky_loss: 31.2114 - val_dice_coef: 0.8020 - val_iou: 0.6705 - val_acc: 0.8504
# Epoch 96/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0047 - tversky_loss: 31.1490 - dice_coef: 0.8630 - iou: 0.7605 - acc: 0.9155WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 794ms/step - loss: 0.0047 - tversky_loss: 31.1487 - dice_coef: 0.8633 - iou: 0.7609 - acc: 0.9157 - val_loss: 0.6516 - val_tversky_loss: 31.2106 - val_dice_coef: 0.8024 - val_iou: 0.6711 - val_acc: 0.8570
# Epoch 97/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0047 - tversky_loss: 31.1510 - dice_coef: 0.8608 - iou: 0.7568 - acc: 0.9237WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 216s 788ms/step - loss: 0.0047 - tversky_loss: 31.1510 - dice_coef: 0.8608 - iou: 0.7568 - acc: 0.9238 - val_loss: 0.6363 - val_tversky_loss: 31.2152 - val_dice_coef: 0.7966 - val_iou: 0.6634 - val_acc: 0.8736
# Epoch 98/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0046 - tversky_loss: 31.1506 - dice_coef: 0.8610 - iou: 0.7575 - acc: 0.9199WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 796ms/step - loss: 0.0046 - tversky_loss: 31.1507 - dice_coef: 0.8609 - iou: 0.7574 - acc: 0.9198 - val_loss: 0.6755 - val_tversky_loss: 31.2140 - val_dice_coef: 0.7987 - val_iou: 0.6660 - val_acc: 0.8601
# Epoch 99/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0047 - tversky_loss: 31.1497 - dice_coef: 0.8626 - iou: 0.7597 - acc: 0.9188WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 217s 792ms/step - loss: 0.0047 - tversky_loss: 31.1498 - dice_coef: 0.8625 - iou: 0.7596 - acc: 0.9187 - val_loss: 0.6509 - val_tversky_loss: 31.2159 - val_dice_coef: 0.7973 - val_iou: 0.6643 - val_acc: 0.8652
# Epoch 100/100
# 273/274 [============================>.] - ETA: 0s - loss: 0.0047 - tversky_loss: 31.1498 - dice_coef: 0.8620 - iou: 0.7589 - acc: 0.9197WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,iou,val_iou,val_tversky_loss,dice_coef,val_dice_coef,val_loss,tversky_loss,val_acc
# 274/274 [==============================] - 218s 794ms/step - loss: 0.0047 - tversky_loss: 31.1498 - dice_coef: 0.8620 - iou: 0.7588 - acc: 0.9197 - val_loss: 0.6764 - val_tversky_loss: 31.2035 - val_dice_coef: 0.8087 - val_iou: 0.6796 - val_acc: 0.8624

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Model evaluation historical plots

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("loss")
plt.legend(loc="lower left")

fig.add_subplot(1,2,2)
plt.title("Training Accuracy")
plt.plot(np.arange(0, N), result.history["acc"], label="train_accuracy")
plt.plot(np.arange(0, N), result.history["val_acc"], label="val_accuracy")
# plt.plot(np.arange(0, N), result.history["accuracy"], label="train_accuracy")
# plt.plot(np.arange(0, N), result.history["val_accuracy"], label="val_accuracy")
plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("UNet_result_static_e"+str(num_epochs))
plt.show()

# %%
#training_gen = TrainAugmentGenerator()
testing_gen = TestAugmentGenerator()

# %% [markdown]
# ### Extract and display model frame, prediction and mask batch

# %%
batch_img,batch_mask = next(testing_gen)
pred_all= model.predict(batch_img)
np.shape(pred_all)
# Out:
# Found 10 images belonging to 1 classes.
# Found 10 images belonging to 1 classes.
# (10, 256, 256, 32)

# %%
for i in range(0,np.shape(pred_all)[0]):
    
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,3,1)
    ax1.imshow(batch_img[i])
    ax1.title.set_text('Actual frame')
    ax1.grid(b=None)
    
    
    ax2 = fig.add_subplot(1,3,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(batch_mask[i],id2code))
    ax2.grid(b=None)
    
    ax3 = fig.add_subplot(1,3,3)
    ax3.set_title('Predicted labels')
    ax3.imshow(onehot_to_rgb(pred_all[i],id2code))
    ax3.grid(b=None)
    
    plt.savefig("UNET_result_"+str(i))
    plt.show()
